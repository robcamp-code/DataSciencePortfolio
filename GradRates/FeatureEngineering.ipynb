# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import copy
#conda install -c conda-forge cufflinks-py
#conda install plotly
import ipywidgets as wg
from IPython.display import display

import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import inspect
import seaborn as sns

from matplotlib import pyplot as plt
init_notebook_mode(connected=True)
cf.go_offline()
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, Normalizer, PolynomialFeatures
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer, SimpleImputer
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.feature_extraction import FeatureHasher
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.base import TransformerMixin, BaseEstimator
pd.options.display.max_columns = 200
pd.options.display.max_rows = 272
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.feature_selection import SelectKBest, VarianceThreshold, RFE, SelectFromModel
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score, mean_absolute_error, make_scorer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.decomposition import PCA
from joblib import dump, load
from Logger import RegressionLogger, FuncTransformer, ColSelect

# %%
import inspect

# %%
log_transformed = 0

# %%
model_log = load("data/model_logging.joblib")

# %%
current_model = copy.deepcopy(model_log[4]["model"])

# %% [markdown]
# # Now Lets Load our original Data

# %%
df = pd.read_csv("data/cleaned_df.csv", index_col="UnitID")

# %%
df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df.drop(["City location of institution (HD2019)", "Institution Name"], axis=1, inplace=True)

# %%
df_black = df.dropna(subset=[df.columns[-7]])

# %%
X_black = df_black.iloc[:,:-14]
y_black = df_black.iloc[:, -7]

# %%
X_black = pd.get_dummies(X_black, drop_first=True)

# %% [markdown]
# # Create Holdout Set

# %%
x_train, x_test, y_train, y_test, sample_x, sample_y = load("objects/holdout_total.joblib")

# %%
X_fe = load("objects/features.joblib")

# %% [markdown]
# ## Model performance on African American Graduation Rates

# %%
params = {
    "Imputer": "SimpleImputer",
    "Scaler": "Standard Scaler",
    "model_name": "Elastic Net",
    "model": current_model,
    "alpha": 0.1,
    "l1_ratio": 0.5,
}

# %%
logger = RegressionLogger(params)

# %%
logger.train_holdout(current_model, x_train, x_test, y_train,  y_test)

# %%
f'train and test mae: {logger.train_mae, logger.mae}'
# Out:
# 'train and test mae: (9.26018194045588, 10.647651386135134)'

# %% [markdown]
# # feature engineering for African American Graduation Rates

# %%
hbcu = X_black.filter(regex="Historically").columns[0]

# %% [markdown]
# ## Log Revenues vs African American Graduation Rates

# %%
fig = go.Figure()

fig.add_trace(
    
    go.Scatter(
        x = np.log(X_black["Core_Expenses"]), y = y_black, mode='markers'
    )
)

fig.update_layout(
    height = 750,
    xaxis = {
        "title": "Log Core Expenses"
    },
    yaxis = {
        "title": "African American Graduation Rates"
    },
    title = "Log Core Expenses vs. African American Graduation Rates"
)
fig.show()
# Out:
# <div>                            <div id="1e89c925-2712-4c84-801e-db4d7f18057d" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e89c925-2712-4c84-801e-db4d7f18057d")) {                    Plotly.newPlot(                        "1e89c925-2712-4c84-801e-db4d7f18057d",                        [{"mode":"markers","type":"scatter","x":[18.61553213185926,17.731547974849544,14.833522511291212,19.170081189384057,15.248883142528449,17.391365116622396,19.160478673192177,17.552039430606577,17.338223497044922,17.6646900742095,17.10257909427675,18.805114413685168,18.7199621087549,17.62008106105556,18.314481042943655,17.17989473942008,17.76817213629196,16.253331278049963,17.535520709313207,18.14738686323825,16.86456215212792,17
389473144521,-1.6382659588507644,-2.063256882265759,-1.6555033486184807,-1.0848607762164078,-2.197016541812481,-1.9431623047691062,-1.3509676532174548,-1.4649811209046795,-1.7574362268987682,11.65430862679392,4.713974015813247,9.052583190994053,1.3063645348144883,0.9876339987562851,-1.988956794625384,-2.2574520113029775,-1.1818543654998486,-1.5916779654636892,-0.43822564656898455,-0.8097852907405753,-2.759327650609011,-2.1329677753800724,0.4028266792963231,-2.5640255079628806,-1.6598274401960913,-2.7344545055053024,-0.9824879676446407,5.026653808137731,0.9214973372001951,0.09649899745346696,0.5369250750940802,0.5688009080137236,5.74636374127656,-1.163967547513686,-0.3259976180872599,-0.047503096670595206,1.375244886458562,0.92 ...

# %% [markdown]
# ## PCA on Enrollment Diversity

# %%
enrollment_diversity = X_black.filter(regex="Percent of total enrollment")

# %%
component1 = pca_pipeline.fit_transform(enrollment_diversity)

# %%
fig = go.Figure()

fig.add_trace(
    
    go.Scatter(
        x = component1.flatten(), y = y_black.to_numpy(), mode='markers'
    )
)

fig.update_layout(
    height = 750,
    width = 1200,
    xaxis = {
        "title": "Enrollment Diversity Component",
        
    },
    yaxis = {
        "title": "African American Graduation Rates"
    },
    title = "Enrollment Diversity Component vs. African American Graduation Rates"
)

fig.show()
# Out:
# <div>                            <div id="a3ed0aa7-8d03-45ea-8d39-a749d11f8e45" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3ed0aa7-8d03-45ea-8d39-a749d11f8e45")) {                    Plotly.newPlot(                        "a3ed0aa7-8d03-45ea-8d39-a749d11f8e45",                        [{"mode":"markers","type":"scatter","x":[-0.6931409785012115,-1.1693352580858922,0.6382455286425059,1.9103981114471023,1.7019252972049372,-0.4048234676730555,0.6352971712676284,-0.8927301433351124,0.30795027139677617,0.6896469152217795,-0.14526681993476512,-0.9743286932952813,-0.9756734889949494,1.7806247733324143,-1.2249639720129808,-0.8993367069109693,-0.6665364967850621,0.6625734484070848,-0.5510804979881203,-1.0705748502229098,-0.9296609382734244,-0.540745092690025,-1.7738024877748622,-0.5684601291189918,-1.1914260028499573,0.8722026027560795,-0.9902856058694868,-1.5891248786121221,-1.2209974497531244,-0.19335084479853828,0.365656601855483,-1.0725197874604537,-1.0431337193550538,-0.6909035770340044,-0.4950767532945814,-0.6313517585618924,-0.21866901889342444,-0.959218779536794,8.804158764565867e-17,0.2898385673743853,0.6054892943330428,-1.0922799654341497,-1.2962653264163624,-0.21356713722795503,0.7325527141320974,-1.3216258999604258,2.591116668034969,-1.1978262562325928,-1.2753974692376162,-1.380363743267093,-0.8332150847769935,1.8126205913147622,7.450958091597759,-0.5271166226112864,-0.9334480548936306,0.6427324628583615,0.06289122479155941,-0.8661880174237755,-0.23805983193444616,-1.1719875877388781,-1.1716677370065438,-0.2450290025159782,-0.27792262197456497,-0.3731284349402866,0.9733275813556885,-0.1351687889825628,0.20151305493439536,0.6657010401519794,0.3194702563444851,-1.143954431292738,-0.9384549886969946,-0.9086516896698548,-1.3841670390585474,-1.1485455321551996,7.244070243224851,1.877849508824655,-0.9315335429452443,-0.5425201989590407,-1.1411430783835617,-0.9003510119248298,2.279952685632357,-0.691844105368405,-1.0206184311089688,-0.8594015205666176,0.19658748467212162,0.2812143243818749,-0.3691632031077923,-1.0543055445027374,-0.6936058633306637,2.0126648776900433,0.43197700449597093,-0.6424871553812352,-0.6199642029226854,-1.0073501024961646,-0.667053076267658,1.6215682328884524,2.2174904169276504,0.11279765757559013,-1.105343522344347,-1.1637302021429698,0.9289090063156311,-1.0193110245327093,-1.0307708833610425,-1.1548229131258079,-1.1412085976602717,-1.085103475579799,0.48497152769921315,1.23237633918112,2.391253789762084,0.03663552248771238,-0.8720385708563839,0.2287946786854316,-0.8081274410845704,0.8366857614107646,0.48856987158443727,-0.1756701463709275,-1.587637141847272,-0.7897112675034772,-1.5643262240684717,-0.8180309803626118,-0.9657702936241952,2.9113863079335522,-0.4739090918194656,-0.9265914365650388,-0.8287309123899954,-0.3486227617862244,-1.0496385217165658,-1.1438712114263205,-0.8873456584272672,1.0525410914180335,1.4586949528947615,-1.1317980520970334,-0.3772115218728905,1.141435822508518,-0.17933256046746968,0.7300737299706196,0.05164903457715786,1.3581534878704367,-1.0437815734167406,-0.6367931010766968,-1.0999643499054776,8.804158764565867e-17,-1.1666970952975129,-0.8146377846528567,-1.2516104293462489,-0.7988967080085697,-1.2042528824608074,5.674048082421889,-0.7144007670870738,2.9251274442954194,2.0388324317194417,3.3580683716641673,-0.6927270117121331,-1.3270910372722742,-1.1158577577514492,-1.6200454485978057,0.18324878601744857,-1.1607221181354554,-1.4721599502757803,-1.0108029876527487,-1.6432780347856326,-1.2815026795623528,-0.5681398876301015,-0.25679518964152837,-0.5269009901540415,0.2251954020924781,0.3455420275415665,0.8782191471838579,2.063976789783889,0.9789775106356916,-0.28480645782876235,-1.179993741601478,-0.976644365017581,-0.32490601915693046,1. ...

# %% [markdown]
# ## PCA on Revenue Distribution

# %%
revenues_df = X_black.iloc[:,1:7]

# %%
component2 = pca_pipeline.fit_transform(revenues_df)

# %%
fig = go.Figure()

fig.add_trace(
    
    go.Scatter(
        x = component2.flatten(), y = y_black.to_numpy(), mode='markers'
    )
)

fig.update_layout(
    height = 650,
    width = 1000,
    xaxis = {
        "title": "Enrollment Diversity Component",
        
    },
    yaxis = {
        "title": "African American Graduation Rates"
    },
    title = "Enrollment Diversity Component vs. African American Graduation Rates"
)

fig.show()
# Out:
# <div>                            <div id="9b2de268-eb11-4a11-905c-bfad7386517e" class="plotly-graph-div" style="height:650px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b2de268-eb11-4a11-905c-bfad7386517e")) {                    Plotly.newPlot(                        "9b2de268-eb11-4a11-905c-bfad7386517e",                        [{"mode":"markers","type":"scatter","x":[-0.5353679364111568,2.307179089244533,-1.7377798116380045,-1.737779811638005,-3.7959712973054733,2.7215288150915216,-1.2730128964913954,-0.9303933906293951,-1.1893536515923901,-0.6995964771554771,-0.5646033289080746,1.5849001782339915,1.447131863170281,-0.8117617647703294,2.0744552861020824,-0.9920596143758796,-0.3061026463339926,-0.45479373359839614,-0.6852770656851628,3.007806406961587,2.
# %%
component3 = pca_pipeline.fit_transform(expenses_distribution)

# %%
pca_pipeline['pca'].explained_variance_ratio_
# Out:
# array([0.30030328])

# %%
fig = go.Figure()

fig.add_trace(
    
    go.Scatter(
        x = component3.flatten(), y = y_black.to_numpy(), mode='markers'
    )
)

fig.update_layout(
    height = 650,
    width = 1000,
    xaxis = {
        "title": "Expenses Distribution Component",
    },
    yaxis = {
        "title": "African American Graduation Rates"
    },
    title = "Enrollment Diversity Component vs. African American Graduation Rates"
)

fig.show()
# Out:
# <div>                            <div id="ec3ec63d-dbd6-4463-8fc8-c1268d6c1e97" class="plotly-graph-div" style="height:650px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec3ec63d-dbd6-4463-8fc8-c1268d6c1e97")) {                    Plotly.newPlot(                        "ec3ec63d-dbd6-4463-8fc8-c1268d6c1e97",                        [{"mode":"markers","type":"scatter","x":[-1.0005375592282197,0.6674946333464696,1.5989770836848956,-0.2124336488654792,-1.2909937615102276,0.09515716621739036,0.09314915319787441,-1.794210247239653,0.1633110360201034,-0.7536756293980735,-2.6468322571364773,2.1345847544517667,0.33023926152612887,-0.032880308853355064,1.3863546126179689,-1.3865268065688527,-1.353856876438178,0.8275380653123949,-0.9803470553666768,1.6337108066314623,-1.9713329177430579,-0.21262832836398182,-1.3533383856408456,-1.1645137705425441,-1.7840187152447353,-0.5122484688505736,-1.3505356638422263,0.4106801615803152,-0.6148419834498153,-1.3393133239294754,-0.1769895226856863,-0.287655789286197,-1.8404156079220189,-0.2052470390743941,-2.431429927750252,-2.713391704010413,-2.0786582937816673,-2.0142057036312764,0.2739435049131193,-1.5100599561097505,-0.12955755457790605,-1.002632499897485,-1.487437695225485,-1.9434204833919952,1.3957164340266712,-1.1809132299550162,-0.11671205735733552,-1.4259992094908556,-1.2445846912754486,-0.8125582644689489,-1.8005325678697344,0.5116720558034384,-2.0490807579465384,1.0417329575270997,-2.176316785355884,1.114895523105779,0.08406616649153584,1.7712239733736315,-0.31554993810866633,1.349097349836573,-1.6118467652030246,0.8508277825969262,0.5883928938994923,-2.424269218542039,2.081829171073008,2.081829171073008,2.081829171073008,2.081829171073008,2.081829171073008,-0.8152056001962152,2.7430789786444434,1.4624211781495309,-1.2063531804447871,-1.1823602554933361,0.3857889579379985,-1.3850902152333524,-0.712624012064067,-2.5531999710464994,-1.1206822911420733,-0.6369752757769804,2.7631816102746467,0.17962082518075484,3.55973299627,1.162059456133746,-0.4028429175883256,2.6365709417751995,0.07807247367851682,0.5274116899200153,-0.6123914298014557,-1.3112132820421143,0.22302859381423684,0.8496451831447396,-1.7486409355947063,-1.3262075801624773,0.6559084811588142,-0.7268582246314086,-0.6365127511213642,-2.223750068645945,-0.5573563997893476,-1.2280809527447194,0.8642076150613119,-0.33725450802857004,1.0947066087362132,-2.012342078211396,-0.13881970667126084,1.5640448797164217,1.8111303368001184,-1.3205933635137908,-0.02308277546249495,-0.6043771056522977,-1.9585870158810252,-0.32952580870017495,-0.8404521907553713,-2.2582897175811203,-0.27515641842812005,-1.5236171446780369,0.20144923889291474,-2.0354508834303977,-0.9685648800279989,-1.2364023581587011,-0.9125894199188556,0.4318189133348082,-2.338781615600835,-2.080154049142288,-0.5663412940657949,-0.8011278627691001,-0.46340751163826127,-1.6662824805143357,-1.031168301415779,-1.0594535339415974,-1.6042528708615755,-1.1609320359844932,-0.9787401758486693,-0.8056530093535235,4.23859381158397,-1.7549188877576463,-1.4568551878118523,-0.3914324572448599,-1.1270065579583146,-0.3675678566576804,-2.042335550430537,-0.053263792231539896,-1.4886026308786358,-1.0465708463217736,-1.4194786256404326,-0.6755530503608327,-1.0946269181145893,-0.8722786140988926,-1.3462968401607998,-1.412218096446619,1.388109599119306,-0.3353270567107014,-1.2074588524993717,-0.18651826958738066,0.17849162654563208,-1.5492274577531964,-0.8953930214524531,0.5746709941141133,-0.5197446980221233,-1.348034155986069,0.2922170857044864,-0.4149492720643958,-1.423527406973152,-1.1304519198571694,2.0504417172831775,-1.7874799421796022,-0.9229553471143721,0.4246660290931855,1.7627556432846456,-0.7049649926910185,0.04657132557214089,1.2138028157613452,1.2138028157613452,0.36589601497385715,0.90189807493 ...

# %% [markdown]
# ## Overall PCA Trends

# %%
pca_pipeline.steps[2] = ('pca', PCA(n_components=5))

# %%
principle_components = pca_pipeline.fit_transform(X_fe)

# %%
y_black.to_numpy().shape
principle_components[:,1]
# Out:
# array([ 8.20120643, -4.85081903,  2.89020866, ...,  2.545542  ,
#         3.64679289,  1.70818302])

# %%
picker = wg.IntSlider(value=0, max=4)
def scatter(component):
    fig = go.Figure()

    fig.add_trace(

        go.Scatter(
            x = principle_components[:,component], y = y_black.to_numpy(), mode='markers'
        )
    )

    fig.update_layout(
        height = 525,
        width = 800,
        xaxis = {
            "title": "First Pricipled Component",
            "range": [-10, 10]
        },
        yaxis = {
            "title": "African American Graduation Rates"
        },
        title = "First Principled Component vs. African American Graduation Rates"
    )

    display(fig.show())
ui = wg.HBox([picker])
out = wg.interactive_output(scatter, {'component': picker})
out.layout.height = '700px'
_ = display(ui, out)
# Out:
# HBox(children=(IntSlider(value=0, max=4),))
# Output(layout=Layout(height='700px'))

# %%
components_df = pd.DataFrame(principle_components, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])

# %%
components_df
# Out:
#             PC1       PC2       PC3       PC4       PC5
# 0     -5.423356  3.151113  2.232848 -4.167132 -0.584118
# 1     -5.896564  6.432013  5.924172 -2.267339 -0.468453
# 2     -2.186617 -2.419037 -0.552543  2.865848 -0.131630
# 3     -0.619987  3.943380 -4.247357  1.906793 -0.148496
# 4     -2.910306  0.501737  1.849377 -2.459682  0.070518
# ...         ...       ...       ...       ...       ...
# 2075  -3.245314 -0.287545 -0.927582  0.358011  1.483925
# 2076  -5.263771  5.412507  3.183121 -1.193943 -0.093535
# 2077  -0.978317  2.299798 -3.956508  2.370685 -0.457610
# 2078  13.738177  4.195906 -1.424597  0.247661 -0.425861
# 2079  13.579212  2.883735 -1.133505  1.892023 -0.428282
#
# [2080 rows x 5 columns]

# %% [markdown]
# ## Interactive Line Fit Plot

# %% [markdown]
# # MultiVariate Plots With Principle Components
