# %%
import pandas as pd
import numpy as np
import xgboost as xgb

#conda install -c conda-forge cufflinks-py
#conda install plotly
import ipywidgets as wg
from IPython.display import display

import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px

import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import inspect
import seaborn as sns

init_notebook_mode(connected=True)
cf.go_offline()
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, Normalizer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer, SimpleImputer
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.compose import ColumnTransformer
pd.options.display.max_columns = 200
pd.options.display.max_rows = 272
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.feature_selection import SelectKBest, VarianceThreshold

from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score, mean_absolute_error, make_scorer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("data/cleaned_df.csv")

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
dependent_df = df.iloc[:,-14:]

# %%
dependent_df.head()
# Out:
#    Graduation rate  total cohort (DRVGR2019)  \
# 0                                       29.0
# 1                                       61.0
# 2                                       26.0
# 3                                        0.0
# 4                                       45.0
#
#    Graduation rate  men (DRVGR2019)  Graduation rate  women (DRVGR2019)  \
# 0                              13.0                                46.0
# 1                              56.0                                65.0
# 2                              28.0                                25.0
# 3                               0.0                                 0.0
# 4                              38.0                                51.0
#
#    Graduation rate  American Indian or Alaska Native (DRVGR2019)  \
# 0                                               26.0
# 1                                               25.0
# 2                                               33.0
# 3                                                NaN
# 4                                               67.0
#
#    Graduation rate  Asian/Native Hawaiian/Other Pacific Islander (DRVGR2019)  \
# 0                                                NaN
# 1                                               58.0
# 2                                               25.0
# 3                                                NaN
# 4                                               56.0
#
#    Graduation rate  Asian (DRVGR2019)  \
# 0                                 NaN
# 1                                58.0
# 2                                25.0
# 3                                 NaN
# 4                                57.0
#
#    Graduation rate  Native Hawaiian or Other Pacific Islander (DRVGR2019)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               40.0
#
#    Graduation rate  Black  non-Hispanic (DRVGR2019)  \
# 0                                               NaN
# 1                                              53.0
# 2                                              12.0
# 3                                               0.0
# 4                                              20.0
#
#    Graduation rate  Hispanic (DRVGR2019)  \
# 0                                    NaN
# 1                                   50.0
# 2                                   32.0
# 3                                    NaN
# 4                                   33.0
#
#    Graduation rate  White  non-Hispanic (DRVGR2019)  \
# 0                                              33.0
# 1                                              67.0
# 2                                              29.0
# 3                                               0.0
# 4                                              50.0
#
#    Graduation rate  two or more races (DRVGR2019)  \
# 0                                             NaN
# 1                                            54.0
# 2                                            20.0
# 3                                             NaN
# 4                                            40.0
#
#    Graduation rate  Race/ethnicity unknown (DRVGR2019)  \
# 0                                                NaN
# 1                                                0.0
# 2                                              100.0
# 3                                                NaN
# 4                                               28.0
#
#    Graduation rate  Nonresident alien (DRVGR2019)  \
# 0                                             NaN
# 1                                            57.0
# 2                                            33.0
# 3                                             NaN
# 4                                            57.0
#
#    Transfer-out rate  total cohort (DRVGR2019)
# 0                                          NaN
# 1                                          NaN
# 2                                         39.0
# 3                                          NaN
# 4                                         14.0

# %%
features = df.iloc[:,:-14]

# %%
features.drop(["City location of institution (HD2019)", "Institution Name"], axis=1, inplace=True)

# %%
features = pd.get_dummies(features, drop_first=True)

# %%
features.head(2)
# Out:
#    UnitID  Core_Revenues  Tuition_And_Fees  Government_Grants  Private_Gifts  \
# 0  180203      7078959.0               2.0               60.0            7.0
# 1  222178    136379482.0              57.0                4.0           17.0
#
#    Investment_Return  Sales_And_Services  Other_Revenues  \
# 0                1.0                 0.0            29.0
# 1               18.0                 0.0             4.0
#
#    Tuition_And_Fees_As_Dollar_Amount  Government_Grants_As_Dollar_Amount  \
# 0                          141579.18                          4247375.40
# 1                        77736304.74                          5455179.28
#
#    Private_Gifts_As_Dollar_Amount  Investment_Return_As_Dollar_Amount  \
# 0                       495527.13                            70789.59
# 1                     23184511.94                         24548306.76
#
#    Sales_And_Services_As_Dollar_Amount  Other_Revenues_As_Dollar_Amount  \
# 0                                  0.0                       2052898.11
# 1                                  0.0                       5455179.28
#
#    Core_Expenses  Instruction_Expenses  Research_Expenses  \
# 0      7294344.0                  29.0                3.0
# 1    121513039.0                  38.0                1.0
#
#    Public_Service_Expenses  Academic_Support_Expenses  \
# 0                      7.0                        3.0
# 1                      2.0                       10.0
#
#    Student_Service_Expenses  Institutional_Support_Expenses  \
# 0                       8.0                            16.0
# 1                      26.0                            24.0
#
#    Other_Core_Expenses  Instruction_Expenses_As_Dollar_Amount  \
# 0                 36.0                             2115359.76
# 1                  0.0                            46174954.82
#
#    Research_Expenses_As_Dollar_Amount  \
# 0                           218830.32
# 1                          1215130.39
#
#    Public_Service_Expenses_As_Dollar_Amount  \
# 0                                 510604.08
# 1                                2430260.78
#
#    Academic_Support_Expenses_As_Dollar_Amount  \
# 0                                   218830.32
# 1                                 12151303.90
#
#    Student_Service_Expenses_As_Dollar_Amount  \
# 0                                  583547.52
# 1                                31593390.14
#
#    Institutional_Support_Expenses_As_Dollar_Amount  \
# 0                                       1167095.04
# 1                                      29163129.36
#
#    Other_Core_Expenses_As_Dollar_Amount  Grand total instructional_staff  \
# 0                            2625963.84                             13.0
# 1                                  0.00                            265.0
#
#    Grand total men instructional_staff  Grand total women instructional_staff  \
# 0                                  7.0                                    6.0
# 1                                154.0                                  111.0
#
#    American Indian or Alaska Native total instructional_staff  \
# 0                                                8.0
# 1                                                1.0
#
#    American Indian or Alaska Native men instructional_staff  \
# 0                                                4.0
# 1                                                1.0
#
#    American Indian or Alaska Native women instructional_staff  \
# 0                                                4.0
# 1                                                0.0
#
#    Asian total instructional_staff  Asian men instructional_staff  \
# 0                              0.0                            0.0
# 1                              3.0                            2.0
#
#    Asian women instructional_staff  \
# 0                              0.0
# 1                              1.0
#
#    Black or African American total instructional_staff  \
# 0                                                0.0
# 1                                               14.0
#
#    Black or African American men instructional_staff  \
# 0                                                0.0
# 1                                                7.0
#
#    Black or African American women instructional_staff  \
# 0                                                0.0
# 1                                                7.0
#
#    Hispanic or Latino total instructional_staff  \
# 0                                           0.0
# 1                                          13.0
#
#    Hispanic or Latino men instructional_staff  \
# 0                                         0.0
# 1                                         8.0
#
#    Hispanic or Latino women instructional_staff  \
# 0                                           0.0
# 1                                           5.0
#
#    Native Hawaiian or Other Pacific Islander total instructional_staff  \
# 0                                                0.0
# 1                                                0.0
#
#    Native Hawaiian or Other Pacific Islander men instructional_staff  \
# 0                                                0.0
# 1                                                0.0
#
#    Native Hawaiian or Other Pacific Islander women instructional_staff  \
# 0                                                0.0
# 1                                                0.0
#
#    White total instructional_staff  White men instructional_staff  \
# 0                              5.0                            3.0
# 1                            228.0                          131.0
#
#    White women instructional_staff  \
# 0                              2.0
# 1                             97.0
#
#    Two or more races total instructional_staff  \
# 0                                          0.0
# 1                                          3.0
#
#    Two or more races men instructional_staff  \
# 0                                        0.0
# 1                                        2.0
#
#    Two or more races women instructional_staff  \
# 0                                          0.0
# 1                                          1.0
#
#    Race/ethnicity unknown total instructional_staff  \
# 0                                               0.0
# 1                                               0.0
#
#    Race/ethnicity unknown men instructional_staff  \
# 0                                             0.0
# 1                                             0.0
#
#    Race/ethnicity unknown women instructional_staff  \
# 0                                               0.0
# 1                                               0.0
#
#    Nonresident alien total instructional_staff  \
# 0                                          0.0
# 1                                          3.0
#
#    Nonresident alien men instructional_staff  \
# 0                                        0.0
# 1                                        3.0
#
#    Nonresident alien women instructional_staff  \
# 0                                          0.0
# 1                                          0.0
#
#    Percent of full-time first-time undergraduates instructional_staff  \
# 0                                               85.0
# 1                                              100.0
#
#    Percent of full-time first-time undergraduates awarded federal  state  local  instructional_staff  \
# 0                                               82.0
# 1                                              100.0
#
#    Grand total men instructional_staff_as_percentage  \
# 0                                              53.85
# 1                                              58.11
#
#    Grand total women instructional_staff_as_percentage  \
# 0                                              46.15
# 1                                              41.89
#
#    American Indian or Alaska Native total instructional_staff_as_percentage  \
# 0                                              61.54
# 1                                               0.38
#
#    American Indian or Alaska Native men instructional_staff_as_percentage  \
# 0                                              30.77
# 1                                               0.38
#
#    American Indian or Alaska Native women instructional_staff_as_percentage  \
# 0                                              30.77
# 1                                               0.00
#
#    Asian total instructional_staff_as_percentage  \
# 0                                           0.00
# 1                                           1.13
#
#    Asian men instructional_staff_as_percentage  \
# 0                                         0.00
# 1                                         0.75
#
#    Asian women instructional_staff_as_percentage  \
# 0                                           0.00
# 1                                           0.38
#
#    Black or African American total instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               5.28
#
#    Black or African American men instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               2.64
#
#    Black or African American women instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               2.64
#
#    Hispanic or Latino total instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               4.91
#
#    Hispanic or Latino men instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               3.02
#
#    Hispanic or Latino women instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               1.89
#
#    Native Hawaiian or Other Pacific Islander total instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Native Hawaiian or Other Pacific Islander women instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    White total instructional_staff_as_percentage  \
# 0                                          38.46
# 1                                          86.04
#
#    White men instructional_staff_as_percentage  \
# 0                                        23.08
# 1                                        49.43
#
#    White women instructional_staff_as_percentage  \
# 0                                          15.38
# 1                                          36.60
#
#    Two or more races total instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               1.13
#
#    Two or more races men instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               0.75
#
#    Two or more races women instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               0.38
#
#    Race/ethnicity unknown total instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Race/ethnicity unknown men instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Race/ethnicity unknown women instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Nonresident alien total instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               1.13
#
#    Nonresident alien men instructional_staff_as_percentage  \
# 0                                               0.00
# 1                                               1.13
#
#    Nonresident alien women instructional_staff_as_percentage  \
# 0                                                0.0
# 1                                                0.0
#
#    Percent of full-time first-time undergraduates instructional_staff_as_percentage  \
# 0                                             653.85
# 1                                              37.74
#
#    Percent of full-time first-time undergraduates awarded federal  state  local  instructional_staff_as_percentage  \
# 0                                             630.77
# 1                                              37.74
#
#    Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)  \
# 0                                               85.0
# 1                                              100.0
#
#    Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)  \
# 0                                               82.0
# 1                                              100.0
#
#    Percent of total enrollment that are American Indian or Alaska Native (DRVEF2013_RV)  \
# 0                                               88.0
# 1                                                0.0
#
#    Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)  \
# 0                                                0.0
# 1                                                1.0
#
#    Percent of total enrollment that are Asian (DRVEF2013_RV)  \
# 0                                                0.0
# 1                                                1.0
#
#    Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)  \
# 0                                                0.0
# 1                                                0.0
#
#    Percent of total enrollment that are Black or African American (DRVEF2013_RV)  \
# 0                                                0.0
# 1                                                8.0
#
#    Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)  ...  \
# 0                                                1.0                    ...
# 1                                               11.0                    ...
#
#    Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority graduate  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority undergraduate  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Enrollment Profile (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Enrollment Profile (HD2018)_Very high undergraduate  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Enrollment Profile (HD2018)_isMissing  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, highly residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily nonresidential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, highly residential  \
# 0                                                  0
# 1                                                  1
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily nonresidential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, highly residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily nonresidential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily residential  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, large  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, medium  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, small  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very large  \
# 0                                                  0
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very small  \
# 0                                                  1
# 1                                                  0
#
#    Carnegie Classification 2018: Size and Setting (HD2018)_isMissing  \
# 0                                                  0
# 1                                                  0
#
#    Historically Black College or University (HD2018)_Yes  \
# 0                                                  0
# 1                                                  0
#
#    Historically Black College or University (HD2018)_isMissing  \
# 0                                                  0
# 1                                                  0
#
#    Institution size category (HD2018)_10,000 - 19,999  \
# 0                                                  0
# 1                                                  0
#
#    Institution size category (HD2018)_20,000 and above  \
# 0                                                  0
# 1                                                  0
#
#    Institution size category (HD2018)_5,000 - 9,999  \
# 0                                                 0
# 1                                                 1
#
#    Institution size category (HD2018)_Under 1,000  \
# 0                                               1
# 1                                               0
#
#    Institution size category (HD2018)_isMissing  \
# 0                                             0
# 1                                             0
#
#    Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution  \
# 0                                                  0
# 1                                                  0
#
#    Parent/child indicator - Finance (FLAGS2019)_Not applicable  \
# 0                                                  1
# 1                                                  1
#
#    Parent/child indicator - Finance (FLAGS2019)_Parent record - includes data from branch campuses  \
# 0                                                  0
# 1                                                  0
#
#    Parent/child indicator - Finance (FLAGS2019)_Partial child record - reports revenues/expenses. Assets/liabilties reported with parent  \
# 0                                                  0
# 1                                                  0
#
#    Sector of institution (HD2018)_Private for-profit, 4-year or above  \
# 0                                                  0
# 1                                                  0
#
#    Sector of institution (HD2018)_Private for-profit, less-than 2-year  \
# 0                                                  0
# 1                                                  0
#
#    Sector of institution (HD2018)_Private not-for-profit, 2-year  \
# 0                                                  0
# 1                                                  0
#
#    Sector of institution (HD2018)_Private not-for-profit, 4-year or above  \
# 0                                                  0
# 1                                                  1
#
#    Sector of institution (HD2018)_Public, 2-year  \
# 0                                              1
# 1                                              0
#
#    Sector of institution (HD2018)_Public, 4-year or above  \
# 0                                                  0
# 1                                                  0
#
#    Sector of institution (HD2018)_isMissing  \
# 0                                         0
# 1                                         0
#
#    State abbreviation (HD2018)_Alaska  \
# 0                                   0
# 1                                   0
#
#    State abbreviation (HD2018)_American Samoa  \
# 0                                           0
# 1                                           0
#
#    State abbreviation (HD2018)_Arizona  State abbreviation (HD2018)_Arkansas  \
# 0                                    0                                     0
# 1                                    0                                     0
#
#    State abbreviation (HD2018)_California  \
# 0                                       0
# 1                                       0
#
#    State abbreviation (HD2018)_Colorado  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_Connecticut  \
# 0                                        0
# 1                                        0
#
#    State abbreviation (HD2018)_Delaware  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_District of Columbia  \
# 0                                                 0
# 1                                                 0
#
#    State abbreviation (HD2018)_Federated States of Micronesia  \
# 0                                                  0
# 1                                                  0
#
#    State abbreviation (HD2018)_Florida  State abbreviation (HD2018)_Georgia  \
# 0                                    0                                    0
# 1                                    0                                    0
#
#    State abbreviation (HD2018)_Guam  State abbreviation (HD2018)_Hawaii  \
# 0                                 0                                   0
# 1                                 0                                   0
#
#    State abbreviation (HD2018)_Idaho  State abbreviation (HD2018)_Illinois  \
# 0                                  0                                     0
# 1                                  0                                     0
#
#    State abbreviation (HD2018)_Indiana  State abbreviation (HD2018)_Iowa  \
# 0                                    0                                 0
# 1                                    0                                 0
#
#    State abbreviation (HD2018)_Kansas  State abbreviation (HD2018)_Kentucky  \
# 0                                   0                                     0
# 1                                   0                                     0
#
#    State abbreviation (HD2018)_Louisiana  State abbreviation (HD2018)_Maine  \
# 0                                      0                                  0
# 1                                      0                                  0
#
#    State abbreviation (HD2018)_Marshall Islands  \
# 0                                             0
# 1                                             0
#
#    State abbreviation (HD2018)_Maryland  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_Massachusetts  \
# 0                                          0
# 1                                          0
#
#    State abbreviation (HD2018)_Michigan  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_Minnesota  \
# 0                                      0
# 1                                      0
#
#    State abbreviation (HD2018)_Mississippi  \
# 0                                        0
# 1                                        0
#
#    State abbreviation (HD2018)_Missouri  State abbreviation (HD2018)_Montana  \
# 0                                     0                                    1
# 1                                     0                                    0
#
#    State abbreviation (HD2018)_Nebraska  State abbreviation (HD2018)_Nevada  \
# 0                                     0                                   0
# 1                                     0                                   0
#
#    State abbreviation (HD2018)_New Hampshire  \
# 0                                          0
# 1                                          0
#
#    State abbreviation (HD2018)_New Jersey  \
# 0                                       0
# 1                                       0
#
#    State abbreviation (HD2018)_New Mexico  \
# 0                                       0
# 1                                       0
#
#    State abbreviation (HD2018)_New York  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_North Carolina  \
# 0                                           0
# 1                                           0
#
#    State abbreviation (HD2018)_North Dakota  \
# 0                                         0
# 1                                         0
#
#    State abbreviation (HD2018)_Northern Marianas  \
# 0                                              0
# 1                                              0
#
#    State abbreviation (HD2018)_Ohio  State abbreviation (HD2018)_Oklahoma  \
# 0                                 0                                     0
# 1                                 0                                     0
#
#    State abbreviation (HD2018)_Oregon  \
# 0                                   0
# 1                                   0
#
#    State abbreviation (HD2018)_Pennsylvania  \
# 0                                         0
# 1                                         0
#
#    State abbreviation (HD2018)_Puerto Rico  \
# 0                                        0
# 1                                        0
#
#    State abbreviation (HD2018)_Rhode Island  \
# 0                                         0
# 1                                         0
#
#    State abbreviation (HD2018)_South Carolina  \
# 0                                           0
# 1                                           0
#
#    State abbreviation (HD2018)_South Dakota  \
# 0                                         0
# 1                                         0
#
#    State abbreviation (HD2018)_Tennessee  State abbreviation (HD2018)_Texas  \
# 0                                      0                                  0
# 1                                      0                                  1
#
#    State abbreviation (HD2018)_Utah  State abbreviation (HD2018)_Vermont  \
# 0                                 0                                    0
# 1                                 0                                    0
#
#    State abbreviation (HD2018)_Virgin Islands  \
# 0                                           0
# 1                                           0
#
#    State abbreviation (HD2018)_Virginia  \
# 0                                     0
# 1                                     0
#
#    State abbreviation (HD2018)_Washington  \
# 0                                       0
# 1                                       0
#
#    State abbreviation (HD2018)_West Virginia  \
# 0                                          0
# 1                                          0
#
#    State abbreviation (HD2018)_Wisconsin  State abbreviation (HD2018)_Wyoming  \
# 0                                      0                                    0
# 1                                      0                                    0
#
#    State abbreviation (HD2018)_isMissing
# 0                                      0
# 1                                      0
#
# [2 rows x 258 columns]

# %%
X = features.copy(deep=True)
y = dependent_df.copy(deep=True).iloc[:, 0]

# %%
pipeline = Pipeline(
    [
        ("imputer", KNNImputer()),
        ("scaler", StandardScaler()),
        ("classifier", ElasticNet(alpha=0.1, l1_ratio=0.5)),
    ]
)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('imputer', KNNImputer()), ('scaler', StandardScaler()),
#                 ('classifier', ElasticNet(alpha=0.1))])

# %%
y_pred = pipeline.predict(x_test)

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 10.016345505156485

# %%
y_pred[:5]
# Out:
# array([29.99800245, 77.98495129, 33.90579771, 25.8826557 , 61.80923343])

# %%
y_test[:5]
# Out:
# 2157    41.0
# 563     81.0
# 789     33.0
# 1325    46.0
# 570     52.0
# Name: Graduation rate  total cohort (DRVGR2019), dtype: float64

# %% [markdown]
# # Baseline Elastic Net Model Predicts within 10%

# %% [markdown]
# ## Lets do some feature engineering and model optimization to see if we can bring that down

# %%
clean_pipeline = Pipeline(
    [
        ("imputer", KNNImputer()),
        ("scaler", StandardScaler()),
    ]
)

# %%
new_features = clean_pipeline.fit_transform(features)

# %%
new_features = pd.DataFrame(new_features, columns=features.columns)

# %% [markdown]
# ### First Step is to make principle components

# %%
# Create PCA Transformer
pca_transformer = PCA(n_components=1)

# %%
df.columns[3:9] # Revenues Distribution
# Out:
# Index(['Tuition_And_Fees', 'Government_Grants', 'Private_Gifts',
#        'Investment_Return', 'Sales_And_Services', 'Other_Revenues'],
#       dtype='object')

# %%
#Transform these columns into a principle component
rev_dist_pc = pca_transformer.fit_transform(new_features[df.columns[3:9]])

# %%
dependent_df.iloc[:,0].to_numpy()
# Out:
# array([29., 61., 26., ..., 41., 54., 58.])

# %%
data = {"rev_dist_pc":rev_dist_pc.flatten(), "target":dependent_df.iloc[:,0].to_numpy()}
df_pc1 = pd.DataFrame(data)

# %%
# Visualize principle component
fig = px.scatter(
    df_pc1, x="rev_dist_pc", y="target", height=600, width=800, trendline='ols',
    title="Revenue Distribution Principle Component", trendline_color_override="black",
    
)
results = px.get_trendline_results(fig) # Calculate R2 of Linear Regression
fig.show()

results.iloc[0]['px_fit_results'].summary()
# Out:
# <div>                            <div id="e39fa628-ee3b-4621-a1ac-e609b0ec5171" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e39fa628-ee3b-4621-a1ac-e609b0ec5171")) {                    Plotly.newPlot(                        "e39fa628-ee3b-4621-a1ac-e609b0ec5171",                        [{"hovertemplate": "rev_dist_pc=%{x}<br>target=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [-4.499265479974207, 0.4975900174505749, -2.188623990231862, 1.6188404994332422, 1.618840499433242, 2.5530036676356955, -2.531823610482684, 1.1807904522973223, 0.8514579109411587, 1.0638061756964297, 0.5759901993861765, 0.5328912386577767, -1.4866509269531847, -1.3615503889945852, 0.6258815153988001, 0.030608981557114168, 0.7525297776362536, -1.9416998294541252, 0.9546483782360353, 0.21415956018799492, 0.42055466646756734, 0.5902765563493485, -2.8058690211384687, -2.242388346581458, -1.704712703972393, -0.05944423519684113, -0.6379075983868122, 0.2507406893052707, 1.53018344728731, -0.6905381648755939, 1.5316808293161919, 0.4916900769671911, -1.001388039496972, 1.3091849565136922, 1.1433022853207877, 0.9151151098639355, -0.031017707047568396, -0.3474768900279, -3.070599409871656, 1.6188404994332422, 1.3590567269427378, -0.33268966456496246, 2.130434297125934, 1.5538945563106157, 1.6188404994332422, 1.6188404994332422, 1.1396146670585174, -0.10110631219784487, 0.04742518450553811, 1.5538945563106157, 1.6188404994332422, 1.059835568100947, 0.9892864597500322, 0.9724314194610932, 1.752292380605021, -3.9529464486727104, 0.9068014576918871, 1.6028101984886796, -4.652533033847261, -4.652533033847261, 1.5538945563106157, 0.006178222887283214, 1.3056548103020056, 0.5988819037000448, 1.2969569113852182, -0.01706233884615461, 0.401355418817644, 1.6188404994332422, -0.9003588115108444, 1.3519910591286504, -2.6803340801083078, -0.32557144619193923, -2.496465026315508, 0.8059035669621235, -0.6256151290071094, -0.7614917280419461, 0.4031849517779706, -0.733286961156471, -0.7772900376809345, 0.31249646732207803, -0.578943625473222, -0.578943625473222, -0.578943625473222, -0.578943625473222, -0.578943625473222, -2.4210602205346596, -1.4513042900892954, -1.293021122423735, 0.789061320128542, 0.9662474971779678, 1.3318917681543117, 1.6188404994332422, 0.8085180094597838, 1.6188404994332422, 0.9872364479811754, 1.6188404994332422, 1.4902383098636989, 0.47356933971681636, 1.6188404994332422, -0.3295377942455406, -2.001397398241771, 1.4210767843895233, -0.4714071963718163, -0.5628097126361337, 0.9671204056540487, -1.1879395633546024, 0.8446018422067907, 0.2405519066611802, 1.2394152126062394, 1.2753583246554505, 0.4592141043717205, -0.8829128946569205, -1.5897020910435482, 0.5340827226023506, 0.6807961479279198, 1.6188404994332422, 1.0523919901835213, 1.3687072924463402, 0.8775802312396473, 1.5923472561477825, -0.7896801394350248, 0.8361960947112475, 0.8741212614074105, 1.3446759046869274, 1.1148362538945786, -2.5430281199979996, 0.9081192816824586, -0.9726387031019113, 0.09518531464224318, 0.2894588829844759, 0.4182079187024345, -0.5932351696418967, -0.0984465340580909, 1.0943752671806501, 0.7616410030885025, 0.9449215162858661, 0.8301796029474975, 0.11324837976961025, -4.383802910149616, 1.1680176917267806, 1.6188404994332422, 0.16203659093849898, 1.4643611340244358, 1.0990652690990603, 1.6188404994332422, 0.8560921544631082, 1.4608831148418844, -0.3089918452302771, 1.4004952884977993, 1.2631952000114692, -0.9302343549745715, 1.305462458808338, -0.08836526398863759, -2.0497037717791566, 0.6457294060189562, 1.0843876715881535, 0.5732592056081515, -1.3391869753001011, -0.327723766344832, 0.8238682496551969, 1.366 ...
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     24.62
# Date:                Sun, 05 Sep 2021   Prob (F-statistic):           7.49e-07
# Time:                        18:25:09   Log-Likelihood:                -10416.
# No. Observations:                2315   AIC:                         2.084e+04
# Df Residuals:                    2313   BIC:                         2.085e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.5352      0.453    113.870      0.000      50.648      52.423
# x1             1.6556      0.334      4.962      0.000       1.001       2.310
# ==============================================================================
# Omnibus:                       24.600   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.249
# Skew:                          -0.088   Prob(JB):                     0.000180
# Kurtosis:                       2.616   Cond. No.                         1.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#polyfit principle component to graduation rate
x =

# %%
# calculate new R2 of polyfitted pc

# %%
df.columns[9:15] # Revenues Dollar Amount
# Out:
# Index(['Tuition_And_Fees_As_Dollar_Amount',
#        'Government_Grants_As_Dollar_Amount', 'Private_Gifts_As_Dollar_Amount',
#        'Investment_Return_As_Dollar_Amount',
#        'Sales_And_Services_As_Dollar_Amount',
#        'Other_Revenues_As_Dollar_Amount'],
#       dtype='object')

# %%
df.columns[16:23] # expenses Distribution
# Out:
# Index(['Instruction_Expenses', 'Research_Expenses', 'Public_Service_Expenses',
#        'Academic_Support_Expenses', 'Student_Service_Expenses',
#        'Institutional_Support_Expenses', 'Other_Core_Expenses'],
#       dtype='object')
