# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import copy
#conda install -c conda-forge cufflinks-py
#conda install plotly
import ipywidgets as wg
from IPython.display import display

import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import inspect
import seaborn as sns

from matplotlib import pyplot as plt
init_notebook_mode(connected=True)
cf.go_offline()
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, Normalizer, PolynomialFeatures
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer, SimpleImputer
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.base import TransformerMixin, BaseEstimator
pd.options.display.max_columns = 200
pd.options.display.max_rows = 272
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.feature_selection import SelectKBest, VarianceThreshold, RFE, SelectFromModel
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score, mean_absolute_error, make_scorer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.decomposition import PCA
from joblib import dump, load
from Logger import RegressionLogger, FuncTransformer, ColSelect

# %%
import inspect

# %%
log_transformed = 0

# %%
model_log = load("data/model_logging.joblib")

# %%
current_model = copy.deepcopy(model_log[0]["model"])

# %% [markdown]
# # Now Lets Load our original Data

# %%
df = pd.read_csv("data/cleaned_df.csv", index_col="UnitID")

# %%
df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df.drop(["City location of institution (HD2019)", "Institution Name"], axis=1, inplace=True)

# %%
X = df.iloc[:, :-14]
y = df.iloc[:,-14]

# %%
df_black = df.dropna(subset=[df.columns[-7]])

# %%
X_black = df_black.iloc[:,:-14]
y_black = df_black.iloc[:, -7]

# %%
X_black = pd.get_dummies(X_black, drop_first=True)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.shape
# Out:
# (2315, 260)

# %%
X_black.shape
# Out:
# (2027, 255)

# %% [markdown]
# # Lets Define Our Pipeline

# %%
num_feats = 200
num_pipe = Pipeline([
    ('Impute', ColumnTransformer([
        ('Impute', KNNImputer(n_neighbors=5), make_column_selector(dtype_include=[np.float16, 'float']))
    ], remainder='drop'
    )),
    ('Scale', StandardScaler())
])

cat_pipe = Pipeline([
    ('Passthrough', ColumnTransformer([
        ('Pass', 'passthrough', make_column_selector(dtype_exclude='float'))
    ], remainder='drop'
    ))
])

preprocessor = FeatureUnion([
    ('numeric', num_pipe),
    ('categorical', cat_pipe)
])

pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', ElasticNet(alpha=0.1, l1_ratio=0.5))
])

# %%
params = {
    "Imputer": "SimpleImputer",
    "Scaler": "Standard Scaler",
    "model_name": "Elastic Net",
    "model": pipeline,
    "alpha": 0.1,
    "l1_ratio": 0.5,
}

# %%
logger = RegressionLogger(params)

# %%
logger.train_update(pipeline, X, y)

# %%
logger.train_mae, logger.mae
# Out:
# (9.853116531480456, 9.771918439442612)

# %% [markdown]
# # Currently Our Train is Worse then our test set due to very poor features
#
#
# <ol>
#     <li>Lets Visualize our current residuals</li>
#     <li>Find trends to improve those residuals</li>
#     <li>See if our feature engineering improves residual plots</li>
# <ol>

# %%
residuals = logger.y_pred - logger.y_test

# %%
logger.y_pred.min()
# Out:
# 18.309593371189003

# %%
resid_data = {
    'y_test': logger.y_test,
    'residuals':residuals,
}

# %%
residual_data = pd.DataFrame(resid_data)

# %%
fig = px.scatter(residual_data, x='y_test', y='residuals')

fig.show()
# Out:
# <div>                            <div id="4c4d753f-3ccb-4453-8a3e-9017fb60318b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4
278.0,37238000.0,9628762.0,222079448.0,296863.0,80103000.0,5662711.0,12331580.0,9115029.0,678547000.0,71945030.0,951419.0,3378123.0,103757062.0,2315834.0,487022877.0,442829256.0,67458221.0,195296582.0,180723344.0,318306554.0,298602947.0,281615845.0,419565917.0,613395729.0,622580679.0,459931431.0,200953031.0,622033913.0,564071563.0,327891531.0,261536936.0,207605094.0,122953837.0,9731505.0,5240558.0,114537000.0,26572639.0,53583038.0,143111123.0,116731040.0,59371619.0,440343000.0,58389769.0,17191547.0,25571072.0,9084526.0,13403292.0,875463.0,1831136.0,955671.0,171266183.0,39172172.0,1244036660.0,742593.0,1522611.0,8012154.0,9180349.0,3093937 ...

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (9.843282558289834, 9.769688430125939)

# %% [markdown]
# # Log Core Expenses

# %%
X_fe['Log_Core_Expenses'] = transformer.log_transform(X_fe.to_numpy(), X_fe.columns.get_loc('Core_Expenses'))

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (9.843125400715497, 9.770545271889365)

# %% [markdown]
# # Lets See if this helps our model at all

# %% [markdown]
# ## It Improves training but not test set so lets do a few more trends to see if we get a significant difference.

# %%
# transforming all dollar amounts to log dollar amounts
for i in X_fe.filter(regex='As_Dollar').columns:
    # replace 0s with 1s to avoid errors with logs
    X_fe[i].replace({0.0: 1.0}, inplace=True)
    iloc = X_fe.columns.get_loc(i)
    X_fe["Log_" + i] = transformer.log_transform(X_fe.to_numpy(), iloc)

# %%
logger.train_update(pipeline, X_fe, y)

# %%
logger.train_mae, logger.mae
# Out:
# (9.745134116623186, 9.738213526654397)

# %% [markdown]
# # Small Improvements with Log Dollar Amounts
#
# ### Schools with graduation rates of 0 and 100 are always outliers. Lets drop those observations to see if we get some improvement

# %%
to_drop = list(y[y==100].index) + list(y[y==0].index)

# %%
X_fe.drop(to_drop, inplace=True)

# %%
y.drop(to_drop, inplace=True)

# %%
X.drop(to_drop, inplace=True)

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (8.803794905007054, 9.514799688949795)

# %% [markdown]
# # Significant improvement with dropped outlier graduation rates

# %%
new_residuals = logger.y_pred - logger.y_test
new_resid_data = {
    'y_test': logger.y_pred,
    'residuals':new_residuals,
}
new_residual_df = pd.DataFrame(new_resid_data)

# %%
fig = px.scatter(new_residual_df, x='y_test', y='residuals')

fig.show()
# Out:
# <div>                            <div id="fa9ca119-8632-48fd-9f26-e0be199335c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa9ca119-8632-48fd-9f26-e0be199335c6")) {                    Plotly.newPlot(                        "fa9ca119-8632-48fd-9f26-e0be199335c6",                        [{"hovertemplate":"y_test=%{x}<br>residuals=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[60.17412815358956,47.20632090034337,51.03348112678747,54.944107953353594,103.5097862107059,63.35328100576406,58.96829766276186,83.67352560972061,51.258909970191134,43.504096744363146,63.55899827668114,34.127058756709154,42.78967121981669,79.1309986326749,42.7026530641889,39.60344464645479,35.9944460946533,54.22913429067033,77.42825511474146,41.90041566384017,55.97087951105187,58.983772380814386,49.92117068646626,95.38241619034453,74.4159708950469,64.71185501071967,64.35998834752708,33.131050141454715,63.4476441242561,42.59897859186043,66.46157836317508,68.54025857006889,39.54390156809617,28.509894346880536,65.80069219698842,76.83501238413581,49.44916475916304,82.57059772148544,50.953948901067236,38.116507643312644,48.29502864434842,55.439839050065785,83.19324601369118,88.96671050207898,53.782652699439105,55.641881007447374,51.80983778988062,51.05999614352876,31.714381587779418,62.579990260064406,58.11580911669012,62.051260729182744,36.503738730858444,44.62159363392877,50.531113618263234,44.685268378570456,50.00962038299759,34.87726679754809,54.76529379314336,43.07200055623775,43.86761594757333,38.77269716712427,41.828946772799156,50.63369007199232,41.38137016343492,47.69138013528199,38.88995291266899,40.24580999848564,37.37396004310039,44.477054292304196,72.74433252577367,65.95623186983606,50.51419508071153,52.04305463246161,48.67203942686906,43.78515946694745,79.11743722124368,57.84831663280411,31.43334947667155,51.85732329179724,69.77003351544704,48.61063495482234,38.729458912156176,83.92310799088001,50.93825301895842,60.74016251212627,55.66004877349269,37.82845280399256,87.25861259978082,69.2984108120157,70.91934680462703,58.99052684063126,47.13150766024163,48.74904235703939,92.84578472148714,57.01290789015024,38.32089552967604,33.088825932451016,67.01890377112973,58.392411565404736,41.928416273882334,60.240372206867605,72.65179930696856,33.52459528795739,52.496016952803494,35.96461327720767,49.96047569569732,40.51362590229879,68.86219127846923,50.38370406584941,40.99576129874421,81.24270671159204,72.80526390849161,40.453728712956064,77.43965405823533,41.851626398440594,33.92290028033617,85.06442876072958,53.33408661662393,30.17459955594036,70.27326988108985,64.66527392998461,51.77909672940315,57.42644225945816,64.7400055405121,50.70643465527476,37.9897891734366,47.70995776232814,67.79273227885363,43.52871571840764,66.44820383077895,51.572535977512395,55.01383876599271,41.24815938257097,55.01572394381249,33.61552089298485,51.55300099735537,51.00384845817501,67.56490766438456,48.71421872713638,40.166731752213266,50.565886715470405,53.146216955875616,92.60052512458766,43.29230305586061,43.95411219112516,55.27135439802119,25.07232543321147,33.73741874368699,42.14657607911498,95.87489137107595,48.702482764064726,59.24698628362241,61.93561663905602,71.97539302350737,24.312768447438554,82.14000372416422,95.2169226065567,30.11179146049577,41.033259652584974,43.79384143359529,76.02514365105807,41.53108955335533,37.34059884415974,39.99770340311498,64.38139189809247,43.05098363370834,28.14547460751784,41.21000539844649,46.28685416114499,35.57714753040166,36.430123487796656,55.711837666070316,80.81407197690385,58.26379033629726,56.25271735688876,69.21787713925833,48.534560639102025,29.23920169498397,51.1 ...

# %% [markdown]
# # Still not a visible Improvement in our residual plots

# %% [markdown]
# ### Next Steps
# <ol>
#     <li>Create Polynomial Features</li>
#     <li>Select the Best Polynomial Features</li>
#     <li>Add them to my model one by one to see if any further improvement is possible</li>
# <ol>

# %%
polyfeatures = Pipeline([
    ('preprocess', preprocessor),
    ('polyfeatures', PolynomialFeatures()),
    ('classifier', ElasticNet(alpha=0.1, l1_ratio=0.5))
])

# %%
logger.train_update(polyfeatures, X_fe, y)
# Out:
# /Users/robertcampbell/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 13264.093879964246, tolerance: 86.15923720462544

# %%
logger.train_mae, logger.mae
# Out:
# (4.745974357213847, 9.72261875300546)

# %% [markdown]
# Significant Improvement in training data but model does not converge due to very large amount of features: lets look at the best features and add them one by one to our model

# %%
feature_names = polyfeatures['polyfeatures'].get_feature_names(X_fe.columns)
coefs = polyfeatures['classifier'].coef_

# %%
best_coefs = sorted(list(zip(feature_names, coefs)), key= lambda x: np.abs(x[1]))

# %%
best_coefs[-10:]
# Out:
# [('Institutional_Support_Expenses Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   0.9949393918240573),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional Institution size category (HD2018)_20,000 and above",
#   1.0065972579896512),
#  ('Other_Core_Expenses Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution',
#   1.0083607661406921),
#  ('Student_Service_Expenses Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   -1.0371406989061598),
#  ('Percent of total enrollment that are Asian (DRVEF2013_RV)',
#   1.057673723412211),
#  ('ACT Composite 75th percentile score (IC2012_RV)', 1.0981545836307822),
#  ('SAT Math 75th percentile score (IC2012_RV)', 1.104405990623068),
#  ('Percent of total enrollment that are Black or African American (DRVEF2013_RV)',
#   -1.1303310964231263),
#  ("Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   1.149916047757369),
#  ('Academic_Support_Expenses Other_Core_Expenses', 1.2769079239503063)]

# %%
# Make polynomial features data frame
poly_pipeline = Pipeline([
    ('preprocess', preprocessor),
    ('polyfeatures', PolynomialFeatures()),
])
poly_data = poly_pipeline.fit_transform(X_fe)
poly_features_df = pd.DataFrame(poly_data, columns=feature_names)

# %%
X_fe[best_coefs[-1][0]] = poly_features_df[best_coefs[-1][0]].to_numpy()

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (8.77115492961566, 9.47422134036818)

# %% [markdown]
# # This New Feature Helped so lets continue adding features until model stops improving

# %% [markdown]
# #### I am only choosing features that are new combinations, instead of features I already have

# %%
best_coefs[-7][0]
# Out:
# 'Student_Service_Expenses Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)'

# %%
X_fe[best_coefs[-7][0]] = poly_features_df[best_coefs[-7][0]].to_numpy()

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (8.729339760134076, 9.508497953832764)

# %% [markdown]
# ## Improved Training but test did not improve. Lets keep adding to be sure

# %%
best_coefs[-8][0]
# Out:
# 'Other_Core_Expenses Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution'

# %%
X_fe[best_coefs[-8][0]] = poly_features_df[best_coefs[-8][0]].to_numpy()

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (8.710753822177841, 9.599688757313936)

# %% [markdown]
# ### Ok Our Model Is clearly moving in the other direction now so lets remove the last two features and use these features for our final model

# %%
X_fe.drop(X_fe.columns[-2:].to_list(), axis=1, inplace=True)

# %%
logger.train_update(pipeline, X_fe, y)
logger.train_mae, logger.mae
# Out:
# (8.77115492961566, 9.47422134036818)

# %% [markdown]
# # Lets Use the top 250 features that came from polyfeatures and train a model

# %%
best_coefs[-250:]
# Out:
# [('Percent of total enrollment that are women (DRVEF2013_RV) State abbreviation (HD2018)_Texas',
#   0.35619013069640126),
#  ('Public_Service_Expenses SAT Critical Reading 75th percentile score (IC2012_RV)',
#   -0.3570800212476769),
#  ("Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   -0.3600259700994858),
#  ('ACT Composite 75th percentile score (IC2012_RV) Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential',
#   0.36032058808163775),
#  ('Student_Service_Expenses White women instructional_staff_as_percentage',
#   -0.36179939285421736),
#  ('Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV) Student-to-faculty ratio (EF2019D)',
#   -0.3632472552618844),
#  ("Private_Gifts Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   0.363325521720771),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Institution size category (HD2018)_isMissing',
#   0.36590588502044885),
#  ("SAT Math 75th percentile score (IC2012_RV)_isNaN Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   0.36644238545710456),
#  ('Asian total instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.3669954219883205),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Traditional",
#   0.36730674229503385),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV)_isNaN Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, large',
#   0.36849846819901566),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Total price for in-district students living off campus (with family)  2012-13 (DRVIC2012_RV)',
#   0.3685725185054382),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional Carnegie Classification 2018: Size and Setting (HD2018)_isMissing",
#   0.3706332422223297),
#  ('Total price for in-state students living off campus (with family)  2012-13 (DRVIC2012_RV)',
#   0.37069031551635395),
#  ('Two or more races men instructional_staff_as_percentage',
#   0.37086893323817866),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n^2',
#   -0.37125339267096585),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV)',
#   0.37163992747855124),
#  ('SAT Math 75th percentile score (IC2012_RV)_isNaN', 0.37196641297684424),
#  ("Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   0.3734154452993798),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional Historically Black College or University (HD2018)_Yes",
#   -0.3739041452886073),
#  ('Sales_And_Services Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields',
#   -0.3742982332674243),
#  ('Black or African American women instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields',
#   0.3748904927666015),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.375618036783361),
#  ('Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage SAT Critical Reading 75th percentile score (IC2012_RV)_isNaN',
#   -0.37722011335403893),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   0.3790979912334508),
#  ('Public_Service_Expenses Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)',
#   -0.37934796268215687),
#  ('Grand total (EF2013B_RV  Undergraduate  Age 25 and over total) State abbreviation (HD2018)_Colorado',
#   -0.38050981482421087),
#  ("Percent of total enrollment that are Black or African American (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-Mixed Traditional/Nontraditional",
#   0.38198015236974575),
#  ('Research_Expenses Native Hawaiian or Other Pacific Islander women instructional_staff',
#   -0.3828459479402188),
#  ('Institutional_Support_Expenses Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)',
#   0.38287724079156255),
#  ("American Indian or Alaska Native women instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   -0.3845516166078717),
#  ('Percent of total enrollment that are White (DRVEF2013_RV)',
#   0.38678038721146),
#  ('Government_Grants Black or African American women instructional_staff',
#   0.38809818613210184),
#  ("Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.38845611737330316),
#  ('Academic_Support_Expenses State abbreviation (HD2018)_Colorado',
#   0.3887039085163362),
#  ('State abbreviation (HD2018)_isMissing^2', 0.38896624588884865),
#  ('State abbreviation (HD2018)_isMissing', 0.38939453562026755),
#  ('Nonresident alien women instructional_staff_as_percentage Percent of total enrollment that are women (DRVEF2013_RV)',
#   -0.3903125545975294),
#  ('White women instructional_staff_as_percentage Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)',
#   0.39248495239491965),
#  ("Government_Grants Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   -0.393906762959584),
#  ("Institutional_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-Mixed Traditional/Nontraditional",
#   0.3941006421395575),
#  ("Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional",
#   -0.39525271703428677),
#  ('White men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n',
#   0.3955960541298901),
#  ('Two or more races women instructional_staff_as_percentage Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   -0.3970696625525731),
#  ('Public_Service_Expenses State abbreviation (HD2018)_Colorado',
#   -0.3973504779441774),
#  ('Asian women instructional_staff_as_percentage Two or more races total instructional_staff_as_percentage',
#   -0.39771767237327554),
#  ('Instruction_Expenses Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)',
#   -0.3984273572736008),
#  ('Student_Service_Expenses Hispanic or Latino men instructional_staff_as_percentage',
#   0.40048703392569873),
#  ('White men instructional_staff_as_percentage Percent of total enrollment that are Asian (DRVEF2013_RV)',
#   -0.4032221462980389),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage^2',
#   0.4036063563176719),
#  ('Instruction_Expenses Nonresident alien women instructional_staff_as_percentage',
#   -0.40390557137215266),
#  ('Two or more races total instructional_staff_as_percentage Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   -0.40421489772176844),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n^2',
#   -0.40436592431846546),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.4044334986953833),
#  ("Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's",
#   -0.4061684581186457),
#  ('State abbreviation (HD2018)_Colorado Log_Investment_Return_As_Dollar_Amount',
#   -0.4063084165900211),
#  ('Black or African American men instructional_staff_as_percentage Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.4076309636157868),
#  ('Private_Gifts Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   0.40856430680610556),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.4088937190695917),
#  ('Student_Service_Expenses State abbreviation (HD2018)_Arizona',
#   -0.4089157168704705),
#  ('Academic_Support_Expenses Carnegie Classification 2018: Enrollment Profile (HD2018)_High undergraduate',
#   -0.40907179567160484),
#  ('Asian men instructional_staff_as_percentage Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   0.4091827113104182),
#  ('Percent of total enrollment that are women (DRVEF2013_RV) Total price for in-state students living off campus (not with family)  2012-13 (DRVIC2012_RV)',
#   0.4091991171067937),
#  ('Institutional_Support_Expenses State abbreviation (HD2018)_District of Columbia',
#   -0.4092648022414912),
#  ('Other_Core_Expenses Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   0.4100034729282287),
#  ('Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV) Total men (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   -0.41134047788914146),
#  ('Instruction_Expenses Historically Black College or University (HD2018)_Yes',
#   -0.41207523928843864),
#  ('Percent of total enrollment that are women (DRVEF2013_RV) Total price for in-district students living off campus (not with family)  2012-13 (DRVIC2012_RV)',
#   0.41366671961472146),
#  ('Two or more races total instructional_staff_as_percentage Percent of total enrollment that are women (DRVEF2013_RV)',
#   -0.41406124500706853),
#  ("Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   0.41458278235046114),
#  ('Institutional_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields',
#   -0.41635694681277585),
#  ("Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   0.41667039597166855),
#  ('Student_Service_Expenses Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential',
#   -0.4170573588792373),
#  ('Nonresident alien women instructional_staff_as_percentage Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.4170649416898144),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-Mixed Traditional/Nontraditional Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   0.4178572650529542),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields",
#   -0.41788276576057837),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total) State abbreviation (HD2018)_Michigan',
#   0.41807255957521555),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional^2",
#   0.41808875462879497),
#  ('Student_Service_Expenses', -0.41827480599115446),
#  ('Instruction_Expenses ACT Composite 75th percentile score (IC2012_RV)',
#   0.41933618005767964),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) State abbreviation (HD2018)_Arizona',
#   -0.42070398219506594),
#  ("Student-to-faculty ratio (EF2019D) Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.42090823830394203),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Total men (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   0.42119691709144913),
#  ('Asian women instructional_staff_as_percentage Institution size category (HD2018)_Under 1,000',
#   0.42145825336483267),
#  ('Other_Revenues Two or more races women instructional_staff_as_percentage',
#   0.42205301906494536),
#  ("Percent of total enrollment that are women (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   0.4220587558881056),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage SAT Math 75th percentile score (IC2012_RV)',
#   -0.42241446485503603),
#  ('Research_Expenses SAT Critical Reading 75th percentile score (IC2012_RV)_isNaN',
#   -0.42262743661419866),
#  ('Government_Grants State abbreviation (HD2018)_Colorado',
#   -0.4248140425655069),
#  ('Government_Grants', -0.4283447829210373),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total) State abbreviation (HD2018)_Colorado',
#   -0.4289016442686212),
#  ('Race/ethnicity unknown men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n',
#   -0.42916547976157704),
#  ('Student_Service_Expenses Percent of total enrollment that are two or more races (DRVEF2013_RV)',
#   0.42922783187493346),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV) Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential',
#   0.4295087513595093),
#  ("Institutional_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   -0.4302157928098658),
#  ('Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV) Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   0.43145309543381677),
#  ("Percent of total enrollment that are White (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   -0.43257292440299805),
#  ('Asian women instructional_staff_as_percentage Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)',
#   -0.4343930626910502),
#  ('Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential',
#   0.4355992514413821),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   -0.4359802675322302),
#  ('White men instructional_staff_as_percentage Log_Investment_Return_As_Dollar_Amount',
#   -0.4361988264576407),
#  ('Other_Revenues Research_Expenses', 0.4372888878043572),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV) State abbreviation (HD2018)_Colorado',
#   0.4409354905035933),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) Institution size category (HD2018)_isMissing',
#   -0.44496836116583977),
#  ('Tuition_And_Fees^2', 0.4461224211466057),
#  ("Academic_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   0.4462531595585679),
#  ('Asian men instructional_staff_as_percentage Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   0.44722377967968296),
#  ('Race/ethnicity unknown women instructional_staff_as_percentage Nonresident alien women instructional_staff_as_percentage',
#   0.4479802255345655),
#  ('Total price for in-district students living off campus (not with family)  2012-13 (DRVIC2012_RV) State abbreviation (HD2018)_Michigan',
#   -0.44847266986142575),
#  ('Total price for in-state students living off campus (not with family)  2012-13 (DRVIC2012_RV) State abbreviation (HD2018)_Michigan',
#   -0.4520438095040295),
#  ('Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.45585982967584265),
#  ('Two or more races men instructional_staff_as_percentage Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV)',
#   -0.4562581851237716),
#  ('Black or African American total instructional_staff_as_percentage State abbreviation (HD2018)_Arizona',
#   -0.45642326314109),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV)',
#   -0.4574370975556744),
#  ('State abbreviation (HD2018)_Minnesota^2', -0.45865574333603776),
#  ('State abbreviation (HD2018)_Minnesota', -0.45880040794084836),
#  ('Private_Gifts Log_Investment_Return_As_Dollar_Amount', -0.4619513820410046),
#  ('Percent of total enrollment that are two or more races (DRVEF2013_RV) Student-to-faculty ratio (EF2019D)',
#   -0.46239503544139615),
#  ('Research_Expenses Student_Service_Expenses', -0.4628048109339359),
#  ('Total price for in-district students living off campus (with family)  2012-13 (DRVIC2012_RV)',
#   0.4632419683699498),
#  ('Private_Gifts Total men (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   0.463783872978894),
#  ("Hispanic or Latino women instructional_staff Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   0.4638335700335075),
#  ('State abbreviation (HD2018)_West Virginia^2', -0.4641978422686902),
#  ('State abbreviation (HD2018)_West Virginia', -0.4642370281513599),
#  ('Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV)',
#   0.46469703073652535),
#  ('White women instructional_staff_as_percentage Percent of total enrollment that are Black or African American (DRVEF2013_RV)',
#   -0.46629689469280033),
#  ('Government_Grants SAT Math 75th percentile score (IC2012_RV)',
#   -0.46681027406546083),
#  ('Asian women instructional_staff_as_percentage White men instructional_staff_as_percentage',
#   -0.46940849916665756),
#  ('American Indian or Alaska Native men instructional_staff_as_percentage Student-to-faculty ratio (EF2019D)',
#   -0.4708829118491957),
#  ('Log_Investment_Return_As_Dollar_Amount^2', -0.471942027867621),
#  ('Log_Investment_Return_As_Dollar_Amount', -0.4721208131955264),
#  ('Percent of total enrollment that are Black or African American (DRVEF2013_RV) Percent of total enrollment that are women (DRVEF2013_RV)',
#   0.47236270918440937),
#  ('Total price for out-of-state students living off campus (with family)  2012-13 (DRVIC2012_RV) ACT Composite 75th percentile score (IC2012_RV)_isNaN',
#   0.47264768216942876),
#  ('Two or more races men instructional_staff_as_percentage Percent of total enrollment that are women (DRVEF2013_RV)',
#   -0.4749312226173471),
#  ("Percent of total enrollment that are Black or African American (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.4797139927017353),
#  ('White women instructional_staff_as_percentage Total price for out-of-state students living off campus (not with family)  2012-13 (DRVIC2012_RV)',
#   0.4823983195651613),
#  ('Instruction_Expenses Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   0.48431784624071),
#  ('Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   -0.4876861928956373),
#  ("Student_Service_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-Mixed Traditional/Nontraditional",
#   0.4881365336531406),
#  ('Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   0.48938939128320413),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n Log_Research_Expenses_As_Dollar_Amount',
#   0.4908768015062807),
#  ('Student_Service_Expenses SAT Math 75th percentile score (IC2012_RV)_isNaN',
#   0.495020878305157),
#  ('Other_Core_Expenses Hispanic or Latino men instructional_staff_as_percentage',
#   -0.49670939861294744),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs^2",
#   -0.4971437731157166),
#  ('Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields State abbreviation (HD2018)_Georgia',
#   0.4992148653335231),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Total price for out-of-state students living off campus (not with family)  2012-13 (DRVIC2012_RV)',
#   -0.49973802497429526),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.5013778095587906),
#  ('Student-to-faculty ratio (EF2019D) Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.5025091925365464),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs State abbreviation (HD2018)_West Virginia",
#   -0.5033104463360585),
#  ("Percent of total enrollment that are Black or African American (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-Mixed Traditional/Nontraditional",
#   0.5048958844686601),
#  ('Other_Core_Expenses Institution size category (HD2018)_Under 1,000',
#   -0.5060420605325658),
#  ('Asian men instructional_staff_as_percentage Percent of total enrollment that are women (DRVEF2013_RV)',
#   -0.5068205546272522),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional",
#   0.5089754450145791),
#  ('Other_Core_Expenses Black or African American women instructional_staff_as_percentage',
#   -0.5123421888033878),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage State abbreviation (HD2018)_Colorado',
#   -0.5123963272222959),
#  ("Other_Core_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   -0.5134647771849786),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)^2',
#   -0.5137156663922768),
#  ('Black or African American men instructional_staff_as_percentage Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential',
#   -0.5155350284236833),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution",
#   -0.5183321970564454),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.5197807287302925),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.5224240056996043),
#  ('Instruction_Expenses^2', -0.5227020994386196),
#  ('Race/ethnicity unknown women instructional_staff_as_percentage ACT Composite 75th percentile score (IC2012_RV)_isNaN',
#   0.5291813726966845),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV)_isNaN',
#   0.5295241351486543),
#  ('Student-to-faculty ratio (EF2019D) State abbreviation (HD2018)_Vermont',
#   0.5305684247023638),
#  ('Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Other Fields',
#   -0.5307946510697578),
#  ('Student_Service_Expenses Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Technology-Related Schools',
#   0.5319320398246866),
#  ('SAT Math 75th percentile score (IC2012_RV)^2', 0.532703181005),
#  ('White women instructional_staff_as_percentage Percent of total enrollment that are women (DRVEF2013_RV)',
#   0.5343522671337343),
#  ('Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV) Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential',
#   -0.5381233611916703),
#  ('Private_Gifts^2', 0.5396793318698544),
#  ('Private_Gifts Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   0.5464147569853435),
#  ("Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's",
#   -0.546463567972431),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.548132411395027),
#  ('Tuition_And_Fees Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)',
#   -0.5483520293819978),
#  ('Research_Expenses^2', 0.5495163906351216),
#  ('White men instructional_staff_as_percentage Race/ethnicity unknown women instructional_staff_as_percentage',
#   -0.5507073988277785),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV)^2',
#   -0.5553601002301521),
#  ("Percent of total enrollment that are White (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   0.5567254175883671),
#  ('Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.5575501629534514),
#  ('Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV) Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)',
#   -0.5594755436092212),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.5647668147339628),
#  ('ACT Composite 75th percentile score (IC2012_RV) State abbreviation (HD2018)_Georgia',
#   0.5647920123734014),
#  ("Percent of total enrollment that are women (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   0.5653877193235908),
#  ('Student-to-faculty ratio (EF2019D) Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.5665617370252782),
#  ('Student-to-faculty ratio (EF2019D) Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields',
#   -0.5675452564142962),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Student-to-faculty ratio (EF2019D)',
#   -0.5679029311163759),
#  ('Percent of total enrollment that are White (DRVEF2013_RV) State abbreviation (HD2018)_Georgia',
#   0.5700645598076896),
#  ('Percent of total enrollment that are White (DRVEF2013_RV) State abbreviation (HD2018)_isMissing',
#   0.5724418846851944),
#  ('Nonresident alien women instructional_staff_as_percentage Student-to-faculty ratio (EF2019D)',
#   -0.5752389709396856),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) State abbreviation (HD2018)_Michigan',
#   -0.5763587841330516),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) Student-to-faculty ratio (EF2019D)',
#   -0.5837531982299993),
#  ('Hispanic or Latino women instructional_staff_as_percentage SAT Math 75th percentile score (IC2012_RV)',
#   -0.5907654336770007),
#  ('Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage',
#   0.5947030048906792),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV)',
#   0.5976763901755037),
#  ('White men instructional_staff_as_percentage State abbreviation (HD2018)_Texas',
#   -0.598110372956384),
#  ('Black or African American women instructional_staff_as_percentage Percent of total enrollment that are White (DRVEF2013_RV)',
#   -0.6057764658513606),
#  ('Percent of total enrollment that are White (DRVEF2013_RV) State abbreviation (HD2018)_Colorado',
#   0.6066887570381805),
#  ('Percent of total enrollment that are women (DRVEF2013_RV) Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV)',
#   -0.6077694432635692),
#  ('Instruction_Expenses Percent of total enrollment that are women (DRVEF2013_RV)',
#   0.616841680766932),
#  ('Institutional_Support_Expenses Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   0.6171164979344704),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Institution size category (HD2018)_Under 1,000',
#   -0.6209802728912915),
#  ("Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   -0.6216350947259052),
#  ("Academic_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   0.6244337616660482),
#  ("Asian women instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   0.6265448703340816),
#  ('Other_Revenues Institution size category (HD2018)_Under 1,000',
#   0.6374739759892308),
#  ('Asian men instructional_staff_as_percentage Black or African American women instructional_staff_as_percentage',
#   -0.641559254561763),
#  ("Student_Service_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Traditional",
#   0.6436622452619439),
#  ('Nonresident alien women instructional_staff_as_percentage ACT Composite 75th percentile score (IC2012_RV)_isNaN',
#   0.6471190648277573),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage Student-to-faculty ratio (EF2019D)',
#   0.6479522505706693),
#  ('Tuition_And_Fees Two or more races men instructional_staff_as_percentage',
#   0.6549197474476157),
#  ('Race/ethnicity unknown men instructional_staff_as_percentage Student-to-faculty ratio (EF2019D)',
#   -0.6574307458995795),
#  ('Student-to-faculty ratio (EF2019D) State abbreviation (HD2018)_Arizona',
#   0.6631897640480782),
#  ('Institutional_Support_Expenses Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily residential',
#   0.6654648888863715),
#  ("Two or more races men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional",
#   0.6736617796237439),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)^2',
#   0.6805040295396091),
#  ('Private_Gifts Instruction_Expenses', -0.7148129755497467),
#  ("Two or more races women instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-Mixed Traditional/Nontraditional",
#   0.720156583153143),
#  ('Asian women instructional_staff_as_percentage State abbreviation (HD2018)_Arizona',
#   0.7346117170860813),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) Total price for out-of-state students living off campus (not with family)  2012-13 (DRVIC2012_RV)',
#   -0.7373462845563744),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.7535576220687407),
#  ('Tuition_And_Fees Log_Investment_Return_As_Dollar_Amount',
#   0.7587822223545873),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819) State abbreviation (HD2018)_Michigan',
#   -0.7759333122615238),
#  ('Private_Gifts Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)',
#   0.7774206448602748),
#  ('Tuition_And_Fees State abbreviation (HD2018)_Michigan',
#   -0.7784349499135895),
#  ("Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.7912178973063957),
#  ("Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   -0.791256684829349),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields",
#   0.8131622671911065),
#  ("Student_Service_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   0.8158996221888194),
#  ('Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage Percent of total enrollment that are White (DRVEF2013_RV)',
#   0.8311415409936981),
#  ('Investment_Return Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily residential',
#   0.8420319197530032),
#  ('Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)',
#   0.9002166228897858),
#  ("White men instructional_staff_as_percentage Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's",
#   0.9235858936224359),
#  ('Instruction_Expenses Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   -0.9256681639225026),
#  ("Academic_Support_Expenses Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional",
#   -0.9278654263325685),
#  ('Hispanic or Latino men instructional_staff_as_percentage State abbreviation (HD2018)_Colorado',
#   0.9409155870747157),
#  ('Percent of total enrollment that are two or more races (DRVEF2013_RV) Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   0.9522654450877356),
#  ('Instruction_Expenses Student_Service_Expenses', 0.9730352038616445),
#  ('Percent of total enrollment that are Black or African American (DRVEF2013_RV) State abbreviation (HD2018)_Colorado',
#   -0.9740708386850552),
#  ('Institutional_Support_Expenses Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   0.9949393918240573),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional Institution size category (HD2018)_20,000 and above",
#   1.0065972579896512),
#  ('Other_Core_Expenses Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution',
#   1.0083607661406921),
#  ('Student_Service_Expenses Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   -1.0371406989061598),
#  ('Percent of total enrollment that are Asian (DRVEF2013_RV)',
#   1.057673723412211),
#  ('ACT Composite 75th percentile score (IC2012_RV)', 1.0981545836307822),
#  ('SAT Math 75th percentile score (IC2012_RV)', 1.104405990623068),
#  ('Percent of total enrollment that are Black or African American (DRVEF2013_RV)',
#   -1.1303310964231263),
#  ("Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819) Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   1.149916047757369),
#  ('Academic_Support_Expenses Other_Core_Expenses', 1.2769079239503063)]

# %%
best_features = [i[0] for i in best_coefs[-250:]]

# %%
X_coefs = poly_features_df[best_features]

# %%
logger.train_update(pipeline, X_coefs, y)
logger.train_mae, logger.mae
# Out:
# (6.82403754527983, 9.865052430256636)

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ### Next steps
# <ol>
#     <li>Manual tuning</li>
#     <li>Define hyperparameter space to search over</li>
#     <li>Repeat with XGBRegressor</li>
# <ol>

# %% [markdown]
# ### With A few Manual Adjustments these are the parameters that work well

# %%
elasticNet_model = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', ElasticNet(alpha=0.01, l1_ratio=0.8))
])

# %%
logger.train_update(elasticNet_model, X_fe, y)

# %%
logger.mae
# Out:
# 9.089534882070993

# %% [markdown]
# # XGBRegressor Tree Based Model

# %%
xgb_params = {
    'objective': 'reg:squarederror',
    'n_estimators': 100,
    'max_depth': 10, # lower values will over fit
    'learning_rate': 0.1, 
}

# %%
xgb_model = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', xgb.XGBRegressor(**xgb_params))
])

# %%
logger.train_update(xgb_model, X_fe, y)

# %%
logger.train_mae, logger.mae
# Out:
# (1.1532141353210172, 8.755205750465393)

# %% [markdown]
# ### Severe overfitting with XGB model training_mae is only 0.38
# lets modify the parameters to reduce overfitting

# %%
xgb_params['max_depth'] = 7 # how deep each tree is allowed to be
xgb_params['learning_rate'] = 0.07 # how fast the model converges
xgb_params['colsample_bytree'] = 0.8 # percentage of features to work with per tree
xgb_params['colsample_bynode'] = 0.9 # percentage of remaining features to work with for each split
xgb_params['alpha'] = 0.9 # L1 regularization parameter
xgb_params['gamma'] = 0.7 # minimum loss required for a split to occur
xgb_params['min_child_weight'] = 10 # stop splitting once the number of samples in a given node hits a certain threshold
xgb_params['n_estimators'] = 200
xgb_params['importance_type'] = 'gain'
xgb_model = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', xgb.XGBRegressor(**xgb_params))
])

# %%
logger.train_update(xgb_model, X_fe, y)

# %%
logger.train_mae, logger.mae
# Out:
# (1.1532141353210172, 8.755205750465393)
# [CV 3/3] END classifier__alpha=0.65, classifier__colsample_bynode=0.7, classifier__colsample_bytree=0.7, classifier__gamma=0.8500000000000002, classifier__learning_rate=0.060000000000000005, classifier__max_depth=10, classifier__min_child_weight=20, classifier__n_estimators=200, classifier__objective=reg:squarederror;, score=9.152 total time=   9.5s
# [CV 1/3] END classifier__alpha=0.65, classifier__colsample_bynode=0.7, classifier__colsample_bytree=0.7, classifier__gamma=0.8500000000000002, classifier__learning_rate=0.060000000000000005, classifier__max_depth=10, classifier__min_child_weight=20, classifier__n_estimators=200, classifier__objective=reg:squarederror;, score=9.302 total time=   9.6s
# [CV 2/3] END classifier__alpha=0.65, classifier__colsample_bynode=0.7, classifier__colsample_bytree=0.7, classifier__gamma=0.8500000000000002, classifier__learning_rate=0.060000000000000005, classifier__max_depth=10, classifier__min_child_weight=20, classifier__n_estimators=200, classifier__objective=reg:squarederror;, score=8.877 total time=   9.9s

# %% [markdown]
# # 8.35% MAE is the accuracy we are able to achieve through intuition and manual tuning. Lets Create a parameter space around these values

# %%
xgb_params # this is the best performing hyperparameters with manual tuning
# Out:
# {'objective': 'reg:squarederror',
#  'n_estimators': 200,
#  'max_depth': 7,
#  'learning_rate': 0.07,
#  'colsample_bytree': 0.8,
#  'colsample_bynode': 0.9,
#  'alpha': 0.9,
#  'gamma': 0.7,
#  'min_child_weight': 10,
#  'importance_type': 'gain'}

# %%
hyperparams = {
    'classifier__objective': ['reg:squarederror'],
    'classifier__n_estimators': np.arange(50,300, 50),
    'classifier__max_depth': np.arange(5,11, 1),
    'classifier__learning_rate': np.arange(0.05, 0.16, 0.01),
    'classifier__colsample_bytree': np.arange(0.6, 1.0, 0.1),
    'classifier__colsample_bynode': np.arange(0.6, 1.0, 0.1),
    'classifier__alpha': np.arange(0.6, 1.0, 0.05),
    'classifier__gamma': np.arange(0.6, 1.0, 0.05),
    'classifier__min_child_weight': [1,5,10,15,20, 25]}

# %%
MAE = make_scorer(mean_absolute_error)

# %%
random_search = RandomizedSearchCV(
    xgb_model, param_distributions=hyperparams, n_iter=1,
    scoring=MAE, n_jobs=4, cv=3, verbose=3, 
    random_state=1001 )

# %%
random_search.fit(X_fe, y)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               FeatureUnion(transformer_list=[('numeric',
#                                                                               Pipeline(steps=[('Impute',
#                                                                                                ColumnTransformer(transformers=[('Impute',
#                                                                                                                                 KNNImputer(),
#                                                                                                                                 <sklearn.compose._column_transformer.make_column_selector object at 0x7fa1ccb94310>)])),
#                                                                                               ('Scale',
#                                                                                                StandardScaler())])),
#                                                                              ('categorical',
#                                                                               Pipeline(steps=[('Passthrough'...
#                                         'classifier__learning_rate': array([0.05, 0.06, 0.07, 0.08, 0.09, 0.1 , 0.11, 0.12, 0.13, 0.14, 0.15]),
#                                         'classifier__max_depth': array([ 5,  6,  7,  8,  9, 10]),
#                                         'classifier__min_child_weight': [1, 5,
#                                                                          10, 15,
#                                                                          20,
#                                                                          25],
#                                         'classifier__n_estimators': array([ 50, 100, 150, 200, 250]),
#                                         'classifier__objective': ['reg:squarederror']},
#                    random_state=1001, scoring=make_scorer(mean_absolute_error),
#                    verbose=3)

# %%
random_search.best_params_
# Out:
# {'classifier__objective': 'reg:squarederror',
#  'classifier__n_estimators': 200,
#  'classifier__min_child_weight': 20,
#  'classifier__max_depth': 10,
#  'classifier__learning_rate': 0.060000000000000005,
#  'classifier__gamma': 0.8500000000000002,
#  'classifier__colsample_bytree': 0.7,
#  'classifier__colsample_bynode': 0.7,
#  'classifier__alpha': 0.65}

# %% [markdown]
# ## These parameters performed worse than my own manual tuning lets use this Model as our final model

# %%
xgb_model['classifier'].feature_importances_
# Out:
# array([0.00525876, 0.00300648, 0.01828825, 0.00494157, 0.00136492,
#        0.00032212, 0.00153424, 0.00639069, 0.0035839 , 0.01931982,
#        0.0041316 , 0.00153889, 0.00160638, 0.0045069 , 0.00510415,
#        0.00199962, 0.00150115, 0.00223099, 0.00961369, 0.00350779,
#        0.00392748, 0.00470225, 0.00307631, 0.00133663, 0.00325324,
#        0.00577953, 0.00381867, 0.00321469, 0.0034086 , 0.00425996,
#        0.0042426 , 0.00087032, 0.00106869, 0.00066736, 0.00436225,
#        0.00110068, 0.00139554, 0.00179468, 0.00176258, 0.00173996,
#        0.0035739 , 0.00115206, 0.00209884, 0.        , 0.        ,
#        0.00241452, 0.00427107, 0.0040734 , 0.00389124, 0.00149985,
#        0.00106999, 0.0003447 , 0.00143239, 0.00136253, 0.00046796,
#        0.01035856, 0.00025309, 0.00244119, 0.0021503 , 0.00303104,
#        0.00182174, 0.00141309, 0.00187748, 0.00399396, 0.00169251,
#        0.00194734, 0.00362818, 0.00247608, 0.00314523, 0.00265638,
#        0.00306303, 0.00149905, 0.0002912 , 0.00137871, 0.00123148,
#        0.0013938 , 0.00330964, 0.00159879, 0.00211036, 0.00121616,
#        0.00209979, 0.00242922, 0.00096663, 0.0009919 , 0.00097672,
#        0.00099956, 0.00146971, 0.00590948, 0.0050356 , 0.00294112,
#        0.01046894, 0.01322846, 0.00341956, 0.01023785, 0.00257367,
#        0.00443402, 0.00281539, 0.00257993, 0.00137881, 0.00218753,
#        0.00319399, 0.00412523, 0.00762706, 0.00649647, 0.00297683,
#        0.02371293, 0.01338526, 0.00624626, 0.01550674, 0.00310111,
#        0.00350803, 0.01293046, 0.0039374 , 0.00264543, 0.02159477,
#        0.00464635, 0.00638591, 0.01511679, 0.00334229, 0.00372721,
#        0.1067851 , 0.13259941, 0.00389715, 0.00603643, 0.00573754,
#        0.00261235, 0.02631444, 0.00306312, 0.00098535, 0.00186562,
#        0.00496618, 0.0187944 , 0.00117047, 0.00269658, 0.00406276,
#        0.00293994, 0.00113018, 0.00361856, 0.0120481 , 0.01451018,
#        0.00640852, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.00201337,
#        0.00055044, 0.00760191, 0.        , 0.        , 0.00092029,
#        0.        , 0.00078421, 0.00038978, 0.00255213, 0.        ,
#        0.00085176, 0.        , 0.00782577, 0.        , 0.0035838 ,
#        0.00085424, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.0028599 , 0.00058125,
#        0.00123675, 0.00117322, 0.00092305, 0.        , 0.00192143,
#        0.        , 0.        , 0.        , 0.        , 0.00094618,
#        0.00145517, 0.00063583, 0.        , 0.00381382, 0.00137283,
#        0.0058289 , 0.        , 0.00273738, 0.        , 0.        ,
#        0.        , 0.00037267, 0.        , 0.00030212, 0.        ,
#        0.00706563, 0.        , 0.00337528, 0.        , 0.0014886 ,
#        0.00089682, 0.        , 0.        , 0.00048785, 0.        ,
#        0.0365222 , 0.00842493, 0.        , 0.        , 0.00422409,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.00125388, 0.00262264, 0.        ,
#        0.        , 0.        , 0.        , 0.0077738 , 0.00270119,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.00145872, 0.        , 0.        ,
#        0.        , 0.        , 0.00047614, 0.00045548, 0.        ,
#        0.00031984, 0.        , 0.        , 0.        , 0.0006421 ,
#        0.        , 0.0011014 , 0.        , 0.0018437 , 0.00144172,
#        0.        , 0.        , 0.00271652, 0.        , 0.        ,
#        0.00746048, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.00361867, 0.00078258, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        ], dtype=float32)

# %%
xgb.plot_tree(xgb_model['classifier'], num_trees=199)
fig = plt.gcf()
fig.set_size_inches(50, 20)

# %% [markdown]
# # Old Features Against Target

# %%
picker1 = wg.Dropdown(
    options=X_fe.columns,
    value=X_fe.columns[0],
    description='Feature:',
    disabled=False,
)


ui = wg.HBox([picker1])


def scatter_residuals(feature):
    fig = make_subplots(
    rows=1, cols=2, 
    column_widths=[0.6, 0.4],
    subplot_titles=(feature, "Residuals")
    )


    _ = fig.add_trace(go.Scatter(
        x = X[feature], y=y, mode='markers'
    ),1,1)

    _ = fig.add_trace(go.Scatter(
        x = X[feature], y=residual_data['residuals'], mode='markers'
    ), 1, 2)
    
    display(fig.show())
    
out = wg.interactive_output(scatter_residuals, {'feature': picker1})
out.layout.height = '700px'
_ = display(ui, out)
# Out:
# HBox(children=(Dropdown(description='Feature:', options=('Core_Revenues', 'Tuition_And_Fees', 'Government_Gran…
# Output(layout=Layout(height='700px'))

# %% [markdown]
# # New Features Against Target

# %%
picker1 = wg.Dropdown(
    options=X_fe.columns,
    value=X_fe.columns[0],
    description='Feature:',
    disabled=False,
)

ui = wg.HBox([picker1])

def scatter_residuals(feature):
    fig = make_subplots(
    rows=1, cols=2, 
    column_widths=[0.6, 0.4],
    subplot_titles=(feature, "Residuals")
    )


    _ = fig.add_trace(go.Scatter(
        x = X_fe[feature], y=y, mode='markers'
    ),1,1)

    _ = fig.add_trace(go.Scatter(
        x = X_fe[feature], y=new_residual_df['residuals'], mode='markers'
    ), 1, 2)
    
    display(fig.show())
    
out = wg.interactive_output(scatter_residuals, {'feature': picker1})
out.layout.height = '700px'
_ = display(ui, out)
# Out:
# HBox(children=(Dropdown(description='Feature:', options=('Core_Revenues', 'Tuition_And_Fees', 'Government_Gran…
# Output(layout=Layout(height='700px'))
