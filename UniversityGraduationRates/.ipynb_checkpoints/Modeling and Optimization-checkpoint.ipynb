# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
import ipywidgets as widgets
from IPython.display import display
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer, SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, VarianceThreshold
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.decomposition import PCA
from functools import reduce
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from autofeat import AutoFeatRegressor 
import plotly.express as px

# %%
# We Are going to do lots of training testing and splitting Lasso Regressions Lets Create a function 
# to make this easier
def train(X, y, alpha):
    
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=40)
    
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(x_train, y_train)
    y_pred = lasso.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    
    names = list(X.columns)
    lasso_coef = lasso.coef_
    coef_dict = dict(zip(names, lasso_coef))
    
    return mse, coef_dict

# %%
def elastic_results(X, y, alpha, L1):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=40)
    
    elastic_net = ElasticNet(alpha=alpha, l1_ratio=L1)
    elastic_net.fit(x_train, y_train)
    y_pred = elastic_net.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    
    names = list(X.columns)
    coef = elastic_net.coef_
    coef_dict = dict(zip(names, coef))
    return mse, coef_dict

# %%
df1 = pd.read_csv("data/cleaned_df.csv", index_col=["UnitID"])

# %%
revenues_distribution = df1.iloc[:,1:7] #Revenues distribution (percentages of total revenues to each area)
revenues_dollar_amount = df1.iloc[:,7:13]
expenses_distribution = df1.iloc[:,13:21] #Expenses as a distribution
expenses_dollar_amount = df1.iloc[:, 21:28]

expenses_dollar_amount.head(3)
# Out:
#           Instruction_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                             2115359.76
# 138558.0                            21084472.08
# 126182.0                            18934322.61
#
#           Research_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                           218830.32
# 138558.0                                0.00
# 126182.0                                0.00
#
#           Public_Service_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                                 510604.08
# 138558.0                                1506033.72
# 126182.0                                1071754.11
#
#           Academic_Support_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                                   218830.32
# 138558.0                                  7530168.60
# 126182.0                                  2500759.59
#
#           Student_Service_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                                  583547.52
# 138558.0                                 4518101.16
# 126182.0                                 6430524.66
#
#           Institutional_Support_Expenses_As_Dollar_Amount  \
# UnitID
# 180203.0                                       1167095.04
# 138558.0                                       9538213.56
# 126182.0                                       5358770.55
#
#           Other_Core_Expenses_As_Dollar_Amount
# UnitID
# 180203.0                            2625963.84
# 138558.0                            6526146.12
# 126182.0                            1786256.85

# %% [markdown]
# ## Staff diversity and Enrollment Diversity as principle components

# %%
staff_total = df1.iloc[:,29:58]  
staff_diversity_distribution = df1.iloc[:, 58:87]
enrollment_diversity = df1.iloc[:,87:100]

enrollment_diversity.head()
# Out:
#           Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)  \
# UnitID
# 180203.0                                               85.0
# 138558.0                                               91.0
# 126182.0                                               98.0
# 100654.0                                               90.0
# 100724.0                                               95.0
#
#           Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)  \
# UnitID
# 180203.0                                               82.0
# 138558.0                                               86.0
# 126182.0                                               92.0
# 100654.0                                               87.0
# 100724.0                                               89.0
#
#           Percent of total enrollment that are American Indian or Alaska Native (DRVEF2013_RV)  \
# UnitID
# 180203.0                                               88.0
# 138558.0                                                0.0
# 126182.0                                                1.0
# 100654.0                                                0.0
# 100724.0                                                0.0
#
#           Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                1.0
# 126182.0                                                2.0
# 100654.0                                                1.0
# 100724.0                                                0.0
#
#           Percent of total enrollment that are Asian (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                1.0
# 126182.0                                                1.0
# 100654.0                                                1.0
# 100724.0                                                0.0
#
#           Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                0.0
# 126182.0                                                0.0
# 100654.0                                                0.0
# 100724.0                                                0.0
#
#           Percent of total enrollment that are Black or African American (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                               12.0
# 126182.0                                                7.0
# 100654.0                                               92.0
# 100724.0                                               91.0
#
#           Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                1.0
# 138558.0                                                6.0
# 126182.0                                               26.0
# 100654.0                                                1.0
# 100724.0                                                1.0
#
#           Percent of total enrollment that are White (DRVEF2013_RV)  \
# UnitID
# 180203.0                                               10.0
# 138558.0                                               78.0
# 126182.0                                               56.0
# 100654.0                                                5.0
# 100724.0                                                3.0
#
#           Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                0.0
# 126182.0                                                5.0
# 100654.0                                                1.0
# 100724.0                                                1.0
#
#           Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                2.0
# 126182.0                                                0.0
# 100654.0                                                0.0
# 100724.0                                                2.0
#
#           Percent of total enrollment that are two or more races (DRVEF2013_RV)  \
# UnitID
# 180203.0                                                0.0
# 138558.0                                                1.0
# 126182.0                                                3.0
# 100654.0                                                0.0
# 100724.0                                                1.0
#
#           Percent of total enrollment that are women (DRVEF2013_RV)
# UnitID
# 180203.0                                               57.0
# 138558.0                                               54.0
# 126182.0                                               56.0
# 100654.0                                               55.0
# 100724.0                                               61.0

# %% [markdown]
# # Age as principle component

# %%
age_df = df1.iloc[:, 100:107]
age_distribution = df1.iloc[:, 107:113]

# %% [markdown]
# # ACT/SAT Scores a principle component

# %%
test_scores = df1.iloc[:,115:118]
test_scores.head()
# Out:
#           SAT Critical Reading 75th percentile score (IC2012_RV)  \
# UnitID
# 180203.0                                              608.0
# 138558.0                                              420.0
# 126182.0                                              530.0
# 100654.0                                              455.0
# 100724.0                                              460.0
#
#           SAT Math 75th percentile score (IC2012_RV)  \
# UnitID
# 180203.0                                       548.0
# 138558.0                                       410.0
# 126182.0                                       550.0
# 100654.0                                       460.0
# 100724.0                                       480.0
#
#           ACT Composite 75th percentile score (IC2012_RV)
# UnitID
# 180203.0                                             25.4
# 138558.0                                             17.0
# 126182.0                                             23.0
# 100654.0                                             19.0
# 100724.0                                             19.0

# %% [markdown]
# # Pre Processing and Modeling (Total Graduation Rates)

# %%
black_grad_rates_df = df1.loc[:,:].dropna(subset=[df1.columns[-1]])

x1 = df1.loc[:,:].drop([df1.columns[-1], df1.columns[-2]], axis=1)
y1 = df1[df1.columns[-2]]
x2 = black_grad_rates_df.drop(df1.columns[-2:], axis=1)
y2 = black_grad_rates_df.loc[:,df1.columns[-2]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x1,y1, test_size=0.25, random_state=39)

# %%
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("classifier", Lasso(alpha=0.1))   
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('classifier', Lasso(alpha=0.1))])

# %%
y_pred = pipeline.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 443.4374267894587

# %%
#visualizing a few of the coeficients

# %%
#_ = plt.plot(range(stop-start), lasso_coef[start:stop])
#_ = plt.xticks(range(stop-start), names[start:stop], rotation=90)
#_ = plt.ylabel("Coeficients")
#plt.show()

# %% [markdown]
# In an Initial Model top 5 Negative Coefficients Were:
#
# <ol>
#     <li>Government_Grants</li>
#     <li>Student_Service_Expense</li>
#     <li>Parent/Child indicator</li>
#     <li>Percent of total enrollment that are Black or African American</li>
#     <li>Grand Total Undergraduate Age 25 and over</li>
# </ol>
# Top 5 Positive Coefficients
# <ol>
#     <li>Grand Total Undergraduate Age Under 25</li>
#     <li>Research_Expenses</li>
#     <li>SAT Math</li>
#     <li>ACT Composite</li>
#     <li>Total Women Uner 25</li>
# </ol>

# %% [markdown]
# ## Feature Engineering #1 Adding Principle Components (Total Grad Rate)

# %%
# First scale x2 using standard scaler
def add_PC(df):
    
    standard_scaler = StandardScaler()
    x1_scaled = standard_scaler.fit_transform(df)

    pca_transform = PCA(n_components=1)

    scaled_df = pd.DataFrame(x1_scaled, columns=df.columns)

    scaled_df["Revenues_Dist_PC"] = pca_transform.fit_transform(scaled_df[revenues_distribution.columns])

    scaled_df["Revenues_Dollar_Amount_PC"] = pca_transform.fit_transform(scaled_df[revenues_dollar_amount.columns])

    scaled_df["Expenses_Dollar_Amount_PC"] = pca_transform.fit_transform(scaled_df[expenses_dollar_amount.columns])

    scaled_df["Expenses_Dist_PC"] = pca_transform.fit_transform(scaled_df[expenses_distribution.columns])

    scaled_df["Staff_Total_PC"] = pca_transform.fit_transform(scaled_df[staff_total.columns])

    scaled_df["Staff_Dist_PC"] = pca_transform.fit_transform(scaled_df[staff_diversity_distribution.columns])

    scaled_df["Age_Total_PC"] = pca_transform.fit_transform(scaled_df[age_df.columns])

    scaled_df["Age_Dist_PC"] = pca_transform.fit_transform(scaled_df[age_distribution.columns])

    scaled_df["Enrollment_Diversity_PC"] = pca_transform.fit_transform(scaled_df[enrollment_diversity.columns])

    scaled_df["Test_Scores_PC"] = pca_transform.fit_transform(scaled_df[test_scores.columns])
    return(scaled_df)
x1_df = add_PC(x1)

# %% [markdown]
# # modeling with new Principle Components

# %%
train(x1_df, y1, 0.1)
# Out:
# (222.21488328278065,
#  {'Core_Revenues': -0.0,
#   'Tuition_And_Fees': 0.0,
#   'Government_Grants': -2.458491289476631,
#   'Private_Gifts': 0.0,
#   'Investment_Return': 0.0,
#   'Sales_And_Services': 0.7109671344876504,
#   'Other_Revenues': 0.06221282578969277,
#   'Tuition_And_Fees_As_Dollar_Amount': -0.0,
#   'Government_Grants_As_Dollar_Amount': -0.0,
#   'Private_Gifts_As_Dollar_Amount': 0.0,
#   'Investment_Return_As_Dollar_Amount': -0.07681795310980447,
#   'Sales_And_Services_As_Dollar_Amount': -0.0,
#   'Other_Revenues_As_Dollar_Amount': -0.14633484055178905,
#   'Core_Expenses': -0.0,
#   'Instruction_Expenses': 0.27761246228508535,
#   'Research_Expenses': 1.090302622268239,
#   'Public_Service_Expenses': -0.7387758178274474,
#   'Academic_Support_Expenses': -0.0,
#   'Student_Service_Expenses': -1.051678231397951,
#   'Institutional_Support_Expenses': -0.0,
#   'Other_Core_Expenses': 0.0,
#   'Instruction_Expenses_As_Dollar_Amount': 0.0,
#   'Research_Expenses_As_Dollar_Amount': -0.0,
#   'Public_Service_Expenses_As_Dollar_Amount': 0.1065617221144287,
#   'Academic_Support_Expenses_As_Dollar_Amount': -0.0678342157450275,
#   'Student_Service_Expenses_As_Dollar_Amount': 1.3465689370871812,
#   'Institutional_Support_Expenses_As_Dollar_Amount': -0.8435498825938813,
#   'Other_Core_Expenses_As_Dollar_Amount': -0.0,
#   'Grand total instructional_staff': 0.0,
#   'Grand total men instructional_staff': 0.0,
#   'Grand total women instructional_staff': -0.0,
#   'American Indian or Alaska Native total instructional_staff': -0.0,
#   'American Indian or Alaska Native men instructional_staff': 0.29764238082799727,
#   'American Indian or Alaska Native women instructional_staff': -0.0,
#   'Asian total instructional_staff': -0.0,
#   'Asian men instructional_staff': -0.0,
#   'Asian women instructional_staff': 0.0,
#   'Black or African American total instructional_staff': 0.0,
#   'Black or African American men instructional_staff': 0.0,
#   'Black or African American women instructional_staff': 0.2520127855029333,
#   'Hispanic or Latino total instructional_staff': -0.0,
#   'Hispanic or Latino men instructional_staff': 0.0,
#   'Hispanic or Latino women instructional_staff': -0.0,
#   'Native Hawaiian or Other Pacific Islander total instructional_staff': -0.17940854376611123,
#   'Native Hawaiian or Other Pacific Islander men instructional_staff': -0.344962807324583,
#   'Native Hawaiian or Other Pacific Islander women instructional_staff': -0.0,
#   'White total instructional_staff': 0.0,
#   'White men instructional_staff': 0.0,
#   'White women instructional_staff': -0.0,
#   'Two or more races total instructional_staff': 0.0,
#   'Two or more races men instructional_staff': 0.161064407722742,
#   'Two or more races women instructional_staff': 0.0,
#   'Race/ethnicity unknown total instructional_staff': -0.0,
#   'Race/ethnicity unknown men instructional_staff': 0.0,
#   'Race/ethnicity unknown women instructional_staff': -0.09156012429487907,
#   'Nonresident alien total instructional_staff': -0.0,
#   'Nonresident alien men instructional_staff': -0.0,
#   'Nonresident alien women instructional_staff': -0.0,
#   'Grand total men instructional_staff_as_percentage': 0.0,
#   'Grand total women instructional_staff_as_percentage': -0.0,
#   'American Indian or Alaska Native total instructional_staff_as_percentage': -0.0,
#   'American Indian or Alaska Native men instructional_staff_as_percentage': -0.13246281247168626,
#   'American Indian or Alaska Native women instructional_staff_as_percentage': 0.0,
#   'Asian total instructional_staff_as_percentage': -0.0,
#   'Asian men instructional_staff_as_percentage': -0.8946751696772807,
#   'Asian women instructional_staff_as_percentage': 0.12272390154736966,
#   'Black or African American total instructional_staff_as_percentage': -0.0,
#   'Black or African American men instructional_staff_as_percentage': -0.2087836062898689,
#   'Black or African American women instructional_staff_as_percentage': -0.0,
#   'Hispanic or Latino total instructional_staff_as_percentage': 0.23987017520469428,
#   'Hispanic or Latino men instructional_staff_as_percentage': 0.5964950516019212,
#   'Hispanic or Latino women instructional_staff_as_percentage': 0.0,
#   'Native Hawaiian or Other Pacific Islander total instructional_staff_as_percentage': 0.0,
#   'Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage': 0.6758756064081777,
#   'Native Hawaiian or Other Pacific Islander women instructional_staff_as_percentage': 0.0,
#   'White total instructional_staff_as_percentage': -0.0,
#   'White men instructional_staff_as_percentage': 0.0,
#   'White women instructional_staff_as_percentage': -0.11532448991288459,
#   'Two or more races total instructional_staff_as_percentage': 0.0,
#   'Two or more races men instructional_staff_as_percentage': 0.23893661757773318,
#   'Two or more races women instructional_staff_as_percentage': -0.0,
#   'Race/ethnicity unknown total instructional_staff_as_percentage': 0.0,
#   'Race/ethnicity unknown men instructional_staff_as_percentage': 0.0,
#   'Race/ethnicity unknown women instructional_staff_as_percentage': 0.005106446432304114,
#   'Nonresident alien total instructional_staff_as_percentage': 0.6081770016721636,
#   'Nonresident alien men instructional_staff_as_percentage': 0.0,
#   'Nonresident alien women instructional_staff_as_percentage': 0.0,
#   'Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)': 0.0,
#   'Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)': -0.5357706610436045,
#   'Percent of total enrollment that are American Indian or Alaska Native (DRVEF2013_RV)': -0.6177285596626128,
#   'Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)': 0.0,
#   'Percent of total enrollment that are Asian (DRVEF2013_RV)': 1.72173375281821,
#   'Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)': 0.0,
#   'Percent of total enrollment that are Black or African American (DRVEF2013_RV)': -1.1157973081256811,
#   'Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)': 0.0,
#   'Percent of total enrollment that are White (DRVEF2013_RV)': 0.9248297257465099,
#   'Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV)': -0.01678264788489614,
#   'Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)': -0.25993993672151716,
#   'Percent of total enrollment that are two or more races (DRVEF2013_RV)': -0.2894576190146026,
#   'Percent of total enrollment that are women (DRVEF2013_RV)': -2.3085543019288557,
#   'Grand total (EF2013B_RV  Undergraduate  Age under 25 total)': 0.0,
#   'Total men (EF2013B_RV  Undergraduate  Age under 25 total)': 0.0,
#   'Total women (EF2013B_RV  Undergraduate  Age under 25 total)': 1.1141495519007174,
#   'Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)': -1.7766178341444427,
#   'Total men (EF2013B_RV  Undergraduate  Age 25 and over total)': -0.0,
#   'Total women (EF2013B_RV  Undergraduate  Age 25 and over total)': -0.2279588503846845,
#   'Incoming_Class_Grand_Total': 0.0,
#   'Grand total (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage': 0.0,
#   'Total men (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage': -0.0,
#   'Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage': 4.295706141180717,
#   'Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage': -0.0,
#   'Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage': -0.3735394064752078,
#   'Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage': 0.0,
#   'Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV)': 1.7764543137131807,
#   'Student-to-faculty ratio (EF2019D)': 0.0,
#   'SAT Critical Reading 75th percentile score (IC2012_RV)': -0.0,
#   'SAT Math 75th percentile score (IC2012_RV)': 2.1377348978477064,
#   'ACT Composite 75th percentile score (IC2012_RV)': 1.1890911263765134,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional": -0.8062355182529178,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional": -0.0,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional": 0.0,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-Mixed Traditional/Nontraditional": -0.21316002249347926,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional": 0.5989283407911112,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Traditional": -0.69875586217,
#   "Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-Mixed Traditional/Nontraditional": -0.43221703618172064,
#   'Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Arts & Sciences Focus': -0.0,
#   'Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields': -0.9245504499235978,
#   "Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant": -1.229713919807341,
#   "Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's": -0.5253053947734185,
#   'Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n': 0.06552785452332303,
#   'Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n': -0.0,
#   'Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n': 0.0,
#   "Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs": 0.38067364769231965,
#   "Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Medium Programs": 0.0,
#   "Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Small Programs": -0.22623089075266156,
#   'Carnegie Classification 2018: Basic (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)': -0.16734352361562208,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Arts, Music & Design Schools': 0.10772177969348445,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Business & Management Schools': 0.2709484479924906,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Engineering Schools': 0.0,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Faith-Related Institutions': -1.771007440080016,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Medical Schools & Centers': 0.48809757116058106,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Health Professions Schools': 1.3155196228904293,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Special Focus Institutions': 0.7956963639803295,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Technology-Related Schools': 0.5108738535091923,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Arts & Design': 0.07338159005604566,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Health Professions': 1.2988964388548754,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Other Fields': -0.0,
#   'Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Technical Professions': 0.6440763216889445,
#   'Carnegie Classification 2018: Basic (HD2018)_Tribal Colleges': 0.0,
#   'Carnegie Classification 2018: Basic (HD2018)_isMissing': 0.14391367363987914,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Exclusively undergraduate four-year': 0.896834569404542,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Exclusively undergraduate two-year': -0.0,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_High undergraduate': 0.0,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority graduate': -0.03549486697818212,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority undergraduate': -0.15865913778500362,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)': -0.021524120122168124,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_Very high undergraduate': 0.16280216629226824,
#   'Carnegie Classification 2018: Enrollment Profile (HD2018)_isMissing': 0.03568461140202147,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, highly residential': 0.014580054161301835,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily nonresidential': -0.731965458180546,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily residential': 0.1594736574120988,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, highly residential': 0.9990530314532723,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily nonresidential': -0.8486580414769304,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily residential': 0.09065150726138704,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, highly residential': 1.143426810308223,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential': -1.541607353538253,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily residential': 0.3796491179687023,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential': -0.5011357998354278,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily nonresidential': 0.0,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily residential': -0.0,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)': -0.017880113473383735,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, large': -0.0,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, medium': -0.1627886062415393,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, small': -0.0,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very large': -0.25221090653982176,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very small': 0.20181746309613033,
#   'Carnegie Classification 2018: Size and Setting (HD2018)_isMissing': 0.010458102963529592,
#   'Historically Black College or University (HD2018)_Yes': -0.0,
#   'Historically Black College or University (HD2018)_isMissing': 2.4059167588616564e-15,
#   'Institution size category (HD2018)_10,000 - 19,999': -0.1232742015745319,
#   'Institution size category (HD2018)_20,000 and above': 0.0,
#   'Institution size category (HD2018)_5,000 - 9,999': -0.21277514338824635,
#   'Institution size category (HD2018)_Under 1,000': 0.0,
#   'Institution size category (HD2018)_isMissing': 0.001523734831151696,
#   'Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution': 1.3809118149477142,
#   'Parent/child indicator - Finance (FLAGS2019)_Not applicable': 0.22871366657363992,
#   'Parent/child indicator - Finance (FLAGS2019)_Parent record - includes data from branch campuses': 0.19448740660226577,
#   'Parent/child indicator - Finance (FLAGS2019)_Partial child record - reports revenues/expenses. Assets/liabilties reported with parent': -2.1284104599329328,
#   'Sector of institution (HD2018)_Private for-profit, 4-year or above': -0.6614733766661403,
#   'Sector of institution (HD2018)_Private for-profit, less-than 2-year': 0.7379455088935318,
#   'Sector of institution (HD2018)_Private not-for-profit, 2-year': -0.0,
#   'Sector of institution (HD2018)_Private not-for-profit, 4-year or above': 0.24861353653817872,
#   'Sector of institution (HD2018)_Public, 2-year': -0.8152344969039954,
#   'Sector of institution (HD2018)_Public, 4-year or above': -1.3160047389784524,
#   'Sector of institution (HD2018)_isMissing': 0.0,
#   'State abbreviation (HD2018)_Alaska': -0.35926163114210247,
#   'State abbreviation (HD2018)_American Samoa': -0.013322941709713982,
#   'State abbreviation (HD2018)_Arizona': -0.6147164720478289,
#   'State abbreviation (HD2018)_Arkansas': -0.4917660079781773,
#   'State abbreviation (HD2018)_California': 1.2891570981692717,
#   'State abbreviation (HD2018)_Colorado': -0.021274836333791743,
#   'State abbreviation (HD2018)_Connecticut': 0.43239565065312296,
#   'State abbreviation (HD2018)_Delaware': -0.23993547678498392,
#   'State abbreviation (HD2018)_District of Columbia': 0.27405075662688244,
#   'State abbreviation (HD2018)_Federated States of Micronesia': 0.00617255723687323,
#   'State abbreviation (HD2018)_Florida': 0.8262388067683787,
#   'State abbreviation (HD2018)_Georgia': -0.9325169395763878,
#   'State abbreviation (HD2018)_Guam': -0.39006794321058386,
#   'State abbreviation (HD2018)_Hawaii': -0.0,
#   'State abbreviation (HD2018)_Idaho': -0.116785431757515,
#   'State abbreviation (HD2018)_Illinois': -0.3808468527695358,
#   'State abbreviation (HD2018)_Indiana': 0.0,
#   'State abbreviation (HD2018)_Iowa': 0.38875837558592224,
#   'State abbreviation (HD2018)_Kansas': 0.0,
#   'State abbreviation (HD2018)_Kentucky': -0.5434404002872056,
#   'State abbreviation (HD2018)_Louisiana': -0.4159687751504767,
#   'State abbreviation (HD2018)_Maine': -0.0,
#   'State abbreviation (HD2018)_Marshall Islands': -0.6103595659587581,
#   'State abbreviation (HD2018)_Maryland': 0.04495854452887347,
#   'State abbreviation (HD2018)_Massachusetts': 0.5717127313213689,
#   'State abbreviation (HD2018)_Michigan': -0.42935461728229823,
#   'State abbreviation (HD2018)_Minnesota': 0.030108752461943895,
#   'State abbreviation (HD2018)_Mississippi': 0.0189512007173389,
#   'State abbreviation (HD2018)_Missouri': 0.610388681598033,
#   'State abbreviation (HD2018)_Montana': -0.2774082587611466,
#   'State abbreviation (HD2018)_Nebraska': -0.06975402004979614,
#   'State abbreviation (HD2018)_Nevada': -0.3443838208976644,
#   'State abbreviation (HD2018)_New Hampshire': 0.1786139258998609,
#   'State abbreviation (HD2018)_New Jersey': -0.0,
#   'State abbreviation (HD2018)_New Mexico': -0.49766711752194376,
#   'State abbreviation (HD2018)_New York': 0.7372964286231292,
#   'State abbreviation (HD2018)_North Carolina': 0.5396839670202339,
#   'State abbreviation (HD2018)_North Dakota': -0.0,
#   'State abbreviation (HD2018)_Northern Marianas': -0.27609850712923084,
#   'State abbreviation (HD2018)_Ohio': -0.07698683584208778,
#   'State abbreviation (HD2018)_Oklahoma': -0.2440870479135606,
#   'State abbreviation (HD2018)_Oregon': 0.1091257865766088,
#   'State abbreviation (HD2018)_Pennsylvania': 1.3957648812530283,
#   'State abbreviation (HD2018)_Puerto Rico': -0.6564567741325967,
#   'State abbreviation (HD2018)_Rhode Island': 0.22884390765170248,
#   'State abbreviation (HD2018)_South Carolina': 0.09672132865547475,
#   'State abbreviation (HD2018)_South Dakota': -0.5742065289278763,
#   'State abbreviation (HD2018)_Tennessee': -0.008615316942203027,
#   'State abbreviation (HD2018)_Texas': -1.077271363752724,
#   'State abbreviation (HD2018)_Utah': 0.02198683183173245,
#   'State abbreviation (HD2018)_Vermont': 0.40210401341826835,
#   'State abbreviation (HD2018)_Virgin Islands': 0.12928374399684833,
#   'State abbreviation (HD2018)_Virginia': 0.08155108154363842,
#   'State abbreviation (HD2018)_Washington': 0.0,
#   'State abbreviation (HD2018)_West Virginia': -0.0,
#   'State abbreviation (HD2018)_Wisconsin': 0.2143837814208534,
#   'State abbreviation (HD2018)_Wyoming': -0.1086381729118256,
#   'State abbreviation (HD2018)_isMissing': 0.0,
#   'Revenues_Dist_PC': 0.0,
#   'Revenues_Dollar_Amount_PC': -0.37947338474863374,
#   'Expenses_Dollar_Amount_PC': -0.0,
#   'Expenses_Dist_PC': 1.942532863905795,
#   'Staff_Total_PC': 0.0,
#   'Staff_Dist_PC': 0.09736992891955015,
#   'Age_Total_PC': 0.0,
#   'Age_Dist_PC': -0.0,
#   'Enrollment_Diversity_PC': 0.0,
#   'Test_Scores_PC': 1.4546693091234397})

# %% [markdown]
# ### Adding more important features
#
# There are some good opportunities for feature engineering expecially after exploring the data.
#
# <ol>
#     <li>Schools that have graduation rates of 100 % or 0 % are clear outliers. This may be because these schools have very small cohort sizes</li>
#     <li>Certain states have a graduation rate much higher than other states. So creating an ordinal variable called state rank may help make better predictions</li>
#     <li> Binning some of my continuous variables also highlighted trends in my EDA. I will bin some of my Principle components and some of my continuous variables to create ordinal variables
# </ol>

# %%
df2 = pd.read_csv("data/feature_engineer.csv", index_col="UnitID")

# %%
class_size = "Incoming_Class_Grand_Total"

# %% [markdown]
# # view size of schools to look for outliers

# %%
sns.scatterplot(data=df1, x=class_size, y=df1.columns[-2])
plt.xlim([0,20000])
# Out:
# (0.0, 20000.0)

# %% [markdown]
# #### many schools small schools with 0 and 100% graduation rates

# %%
var = "Rev"
for i in x1_df.columns:
    if var in i:
        print(i)
# Out:
# Core_Revenues
# Other_Revenues
# Other_Revenues_As_Dollar_Amount
# Revenues_Dist_PC
# Revenues_Dollar_Amount_PC

# %% [markdown]
# ## Lets create Categorical ranking variables (Total Graduation Rate)

# %%
def cat_rank(df, category, agg_func, target):
    group = df.groupby(by=category)
    group_agg = group.agg([agg_func])[df.columns[target]]
    group_rank = group_agg.sort_values(agg_func)\
        .reset_index().reset_index()\
        .loc[:,[category, "index"]].set_index(category)
    group_rank.columns = ["rank"]
    group_rank["rank"] = group_rank["rank"].apply(lambda x: x + 1)
    group_rank_map = dict(zip(group_rank.index.to_numpy(),group_rank["rank"].to_numpy()))
    return group_rank_map

state_map = cat_rank(df2, "State", "mean", -2)
carnegie_basic_map = cat_rank(df2, "Carnegie_Classification_Basic", "mean", -2)
sector_map = cat_rank(df2, "Sector", "mean", -2)
carnegie_size_map = cat_rank(df2, "Carnegie_Classification_Size_Setting", "mean", -2)

# %%
cat_ranks_df = pd.concat([df2["State"].replace(state_map),
 df2["Carnegie_Classification_Size_Setting"].replace(carnegie_size_map),
 df2["Sector"].replace(sector_map),
 df2["Carnegie_Classification_Basic"].replace(carnegie_basic_map)], axis=1)

# %%
df1.reset_index(inplace=True)

# %%
cat_ranks_df.reset_index(inplace=True)

# %%
df1 = cat_ranks_df.merge(df1, on="UnitID", how="outer")

# %%
df1.set_index("UnitID", inplace=True)

# %% [markdown]
# ### Add Principle Components

# %%
df1 = add_PC(df1)
# Out:
#          State  Carnegie_Classification_Size_Setting    Sector  \
# 0    -1.767978                              0.417381 -2.496614
# 1    -1.556341                              1.480825  0.813174
# 2    -1.838523                             -0.007996 -0.841720
# 3     0.983302                             -1.284128 -1.669167
# 4    -0.427611                             -0.858750 -1.669167
# ...        ...                                   ...       ...
# 2256  1.406576                              1.480825  0.813174
# 2257 -1.838523                              1.055447  0.813174
# 2258 -0.286519                             -0.220684 -0.841720
# 2259 -0.286519                             -1.071439 -2.496614
# 2260  0.983302                              0.204693  0.813174
#
#       Carnegie_Classification_Basic  Core_Revenues  Tuition_And_Fees  \
# 0                         -2.125329      -0.332654         -1.898769
# 1                          0.003354      -0.094202         -0.004451
# 2                         -1.194030      -0.215710         -1.382137
# 3                          0.003354       0.055346          1.476561
# 4                         -0.129689      -0.337542          1.235466
# ...                             ...            ...               ...
# 2256                      -0.528817      -0.195143          0.615508
# 2257                       1.466823      -0.315548         -0.004451
# 2258                       0.003354      -0.002291         -0.486641
# 2259                      -1.327073      -0.311485         -0.968831
# 2260                      -0.395774      -0.246752          1.228578
#
#       Government_Grants  Private_Gifts  Investment_Return  Sales_And_Services  \
# 0              3.744376      -0.288495          -0.288510           -0.070603
# 1             -0.493537       0.400692           1.173166           -0.070603
# 2              0.490264      -0.633089          -0.374490           -0.070603
# 3             -0.796246      -0.770926          -0.374490           -0.070603
# 4             -0.796246      -0.770926          -0.374490            9.529278
# ...                 ...            ...                ...                 ...
# 2256          -0.720568      -0.288495           0.915223           -0.070603
# 2257          -0.644891       0.538529           1.345128           -0.070603
# 2258           0.490264      -0.288495          -0.116548           -0.070603
# 2259           0.490264      -0.702008          -0.374490           -0.070603
# 2260          -0.281642      -0.770926          -0.374490            0.477962
#
#       ...  Revenues_Dist_PC  Revenues_Dollar_Amount_PC  \
# 0     ...         -4.464531                  -0.532076
# 1     ...          0.391459                  -0.109449
# 2     ...         -2.151414                  -0.403285
# 3     ...          1.695114                   0.089010
# 4     ...          2.590791                  -0.543544
# ...   ...               ...                        ...
# 2256  ...          1.029681                  -0.306174
# 2257  ...          0.571416                  -0.505036
# 2258  ...         -0.687367                  -0.068916
# 2259  ...         -1.063777                  -0.523723
# 2260  ...          1.284422                  -0.397172
#
#       Expenses_Dollar_Amount_PC  Expenses_Dist_PC  Staff_Total_PC  \
# 0                     -0.814648          1.272085       -0.939467
# 1                      0.008299         -0.825458       -0.387722
# 2                     -0.587589          0.341684       -1.228604
# 3                      0.310006         -0.234558       -0.255628
# 4                     -0.826601         -1.191051       -1.738774
# ...                         ...               ...             ...
# 2256                  -0.400918         -0.381990       -1.154602
# 2257                  -0.686789         -0.999734       -1.624949
# 2258                  -0.003062          0.882687        0.319148
# 2259                  -0.769178         -0.406638       -1.755156
# 2260                  -0.596742         -1.567571       -1.736609
#
#       Staff_Dist_PC  Age_Total_PC  Age_Dist_PC  Enrollment_Diversity_PC  \
# 0         -0.157478     -1.432238     1.776975                -0.843404
# 1         -1.316237     -0.466580    -2.215936                -1.086473
# 2         -0.849173     -0.486628    -1.151835                -0.954775
# 3          0.046523      2.150880     1.221112                 3.061979
# 4         -0.458971     -1.467873     3.857727                 1.045376
# ...             ...           ...          ...                      ...
# 2256      -1.457053     -0.069645    -1.709113                -1.342184
# 2257      -1.060017     -1.180861    -2.315913                -1.505488
# 2258      -0.628025      2.327980    -0.197479                -0.876760
# 2259      -1.435448     -0.283526     0.478592                -0.771481
# 2260       2.748608     -0.863340     3.467048                 2.526021
#
#       Test_Scores_PC
# 0           0.237969
# 1           0.978416
# 2          -4.704132
# 3           0.977173
# 4          -1.055227
# ...              ...
# 2256        0.050309
# 2257       -0.672426
# 2258       -0.595893
# 2259       -1.607918
# 2260        0.003613
#
# [2261 rows x 269 columns]

# %% [markdown]
# ## Remove Outliers

# %%
lower_bound = df1[df1.columns[-2]].quantile(0.001)

# %%
upper_bound = df1[df1.columns[-2]].quantile(0.999)

# %%
upper_bound
# Out:
# 100.0

# %%
filt1 = df1[df1.columns[-2]] != 100
filt2 = df1[df1.columns[-2]] != 0

# %%
df1 = df1[filt1 & filt2] # these graduation rates are just not feasible for a regular sized institution

# %% [markdown]
# # Now Lets Try Again with New Features
#
# Also we will see that because we have so many features that are collinear an elastic net will have slightly better performance

# %%
x3 = df1.drop(df1.columns[-2:], axis=1)
y3 = df1[df1.columns[-2]]

# %%
mse, coefficients = train(x3, y3, 0.1)
# Out:
# /Users/robertcampbell/Desktop/DSP Env/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133001.81140276504, tolerance: 77.37586349557522
#   model = cd_fast.enet_coordinate_descent(

# %%
mse
# Out:
# 175.7876440024245

# %%
mse, coefficients = elastic_results(x3, y3, 0.1, 0.5)
# Out:
# /Users/robertcampbell/Desktop/DSP Env/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128726.25355890252, tolerance: 77.37586349557522
#   model = cd_fast.enet_coordinate_descent(

# %%
mse
# Out:
# 172.97292195890228

# %%
sorted(coefficients.items(), key=lambda item: item[1])
# Out:
# [('Parent/child indicator - Finance (FLAGS2019)_Partial child record - reports revenues/expenses. Assets/liabilties reported with parent',
#   -2.149694341924917),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Faith-Related Institutions',
#   -1.1856564326076862),
#  ('Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -1.1793333294603863),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -1.0036880150002492),
#  ('Institution size category (HD2018)_10,000 - 19,999', -0.8776106707015328),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily nonresidential',
#   -0.652051851713388),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily residential',
#   -0.4158180393560272),
#  ('State abbreviation (HD2018)_Illinois', -0.41037648337639765),
#  ('Nonresident alien women instructional_staff_as_percentage',
#   -0.36540252051924604),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority graduate',
#   -0.31146703586636554),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: Very High Research Activity\r\n',
#   -0.27352247417382064),
#  ('American Indian or Alaska Native men instructional_staff_as_percentage',
#   -0.24684363403014684),
#  ('American Indian or Alaska Native women instructional_staff',
#   -0.22192351858996015),
#  ('Native Hawaiian or Other Pacific Islander total instructional_staff',
#   -0.19854066256137864),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral Universities: High Research Activity\r\n',
#   -0.18724599412656445),
#  ('State abbreviation (HD2018)_Texas', -0.18376631821925682),
#  ('Student_Service_Expenses', -0.17154879706873447),
#  ("Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Associate's Dominant",
#   -0.15186186830721873),
#  ('Public_Service_Expenses', -0.14959536226384063),
#  ('Percent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1819)',
#   -0.14799987220910246),
#  ('Race/ethnicity unknown women instructional_staff_as_percentage',
#   -0.14060745720705528),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, highly residential',
#   -0.12999723324821505),
#  ('Government_Grants', -0.1141593445435483),
#  ('Asian total instructional_staff_as_percentage', -0.10119539978264501),
#  ('White men instructional_staff_as_percentage', -0.07174720780108709),
#  ('Hispanic or Latino women instructional_staff', -0.06510129538658621),
#  ('State abbreviation (HD2018)_New York', -0.061015164879764196),
#  ('Black or African American men instructional_staff', -0.056802330273718935),
#  ('Nonresident alien men instructional_staff', -0.04924059682089336),
#  ('Asian men instructional_staff_as_percentage', -0.04807992613074778),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Majority undergraduate',
#   -0.040497777011984606),
#  ('Percent of total enrollment that are Black or African American (DRVEF2013_RV)',
#   -0.03961210378054186),
#  ('Two or more races women instructional_staff_as_percentage',
#   -0.03591584012568619),
#  ('Percent of total enrollment that are Race/ethnicity unknown (DRVEF2013_RV)',
#   -0.032210363703349176),
#  ('White women instructional_staff', -0.03186303945573637),
#  ('Asian total instructional_staff', -0.03052836353373452),
#  ('Asian men instructional_staff', -0.020509561346663666),
#  ('Native Hawaiian or Other Pacific Islander men instructional_staff',
#   -0.01676685646916126),
#  ('Hispanic or Latino women instructional_staff_as_percentage',
#   -0.011150273045272331),
#  ('Grand total women instructional_staff_as_percentage', -0.00993786413326623),
#  ('Grand total women instructional_staff', -0.009327867044509415),
#  ('Academic_Support_Expenses', -0.007234829730014883),
#  ('SAT Critical Reading 75th percentile score (IC2012_RV)',
#   -0.0056507423622041576),
#  ('Race/ethnicity unknown men instructional_staff', -0.005331633018699182),
#  ('Grand total (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   -0.0013721456831798646),
#  ('Total men (EF2013B_RV  Undergraduate  Age under 25 total)',
#   -0.0007199551646614161),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   -0.0006085687456372141),
#  ('Incoming_Class_Grand_Total', -0.00012373728827324087),
#  ('Grand total (EF2013B_RV  Undergraduate  Age under 25 total)',
#   -9.387468952796801e-05),
#  ('Sales_And_Services_As_Dollar_Amount', -4.6850041012864726e-08),
#  ('Research_Expenses_As_Dollar_Amount', -2.3292583587729188e-08),
#  ('Tuition_And_Fees_As_Dollar_Amount', -1.8493440747833488e-08),
#  ('Institutional_Support_Expenses_As_Dollar_Amount', -1.3943300068220246e-08),
#  ('Investment_Return_As_Dollar_Amount', -1.3082698328225477e-08),
#  ('Other_Revenues_As_Dollar_Amount', -1.0313696310613455e-08),
#  ('Academic_Support_Expenses_As_Dollar_Amount', -8.468078096589278e-09),
#  ('Private_Gifts_As_Dollar_Amount', -3.6543520821297544e-09),
#  ('Core_Expenses', -3.215778112683849e-09),
#  ('Instruction_Expenses_As_Dollar_Amount', -2.5757731090632904e-09),
#  ('Institutional_Support_Expenses', 0.0),
#  ('American Indian or Alaska Native total instructional_staff', 0.0),
#  ('Black or African American total instructional_staff', 0.0),
#  ('Hispanic or Latino total instructional_staff', -0.0),
#  ('Native Hawaiian or Other Pacific Islander women instructional_staff', -0.0),
#  ('Two or more races men instructional_staff', -0.0),
#  ('Race/ethnicity unknown total instructional_staff', -0.0),
#  ('Nonresident alien total instructional_staff', 0.0),
#  ('American Indian or Alaska Native total instructional_staff_as_percentage',
#   0.0),
#  ('Asian women instructional_staff_as_percentage', -0.0),
#  ('Black or African American total instructional_staff_as_percentage', 0.0),
#  ('Black or African American men instructional_staff_as_percentage', -0.0),
#  ('Hispanic or Latino total instructional_staff_as_percentage', 0.0),
#  ('Native Hawaiian or Other Pacific Islander women instructional_staff_as_percentage',
#   0.0),
#  ('White total instructional_staff_as_percentage', -0.0),
#  ('Two or more races total instructional_staff_as_percentage', 0.0),
#  ('Race/ethnicity unknown total instructional_staff_as_percentage', -0.0),
#  ('Nonresident alien total instructional_staff_as_percentage', -0.0),
#  ('Percent of total enrollment that are Native Hawaiian or Other Pacific Islander (DRVEF2013_RV)',
#   0.0),
#  ('Total men (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage',
#   0.0),
#  ('Total men (EF2013B_RV  Undergraduate  Age 25 and over total)_as_percentage',
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional",
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Nontraditional",
#   0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-High Traditional",
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: High Vocational & Technical-Mixed Traditional/Nontraditional",
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Nontraditional",
#   0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-High Traditional",
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Associate's Colleges: Mixed Transfer/Vocational & Technical-Mixed Traditional/Nontraditional",
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Arts & Sciences Focus',
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's",
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Doctoral/Professional Universities\r\n',
#   -0.0),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Small Programs",
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)',
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Arts, Music & Design Schools',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Business & Management Schools',
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Engineering Schools',
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Medical Schools & Centers',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Health Professions Schools',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Special Focus Institutions',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Arts & Design',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Health Professions',
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Other Fields',
#   -0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Two-Year: Technical Professions',
#   0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_Tribal Colleges', 0.0),
#  ('Carnegie Classification 2018: Basic (HD2018)_isMissing', -0.0),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Exclusively undergraduate two-year',
#   -0.0),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_High undergraduate',
#   -0.0),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)',
#   -0.0),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Very high undergraduate',
#   0.0),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_isMissing', -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, highly residential',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, large, primarily nonresidential',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily nonresidential',
#   0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, primarily residential',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily residential',
#   0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Not applicable, not in Carnegie universe (not accredited or nondegree-granting)',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, large',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, medium',
#   0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, small',
#   0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very large',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Two-year, very small',
#   -0.0),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_isMissing', -0.0),
#  ('Historically Black College or University (HD2018)_Yes', 0.0),
#  ('Historically Black College or University (HD2018)_isMissing', -0.0),
#  ('Institution size category (HD2018)_20,000 and above', -0.0),
#  ('Institution size category (HD2018)_5,000 - 9,999', -0.0),
#  ('Institution size category (HD2018)_Under 1,000', -0.0),
#  ('Institution size category (HD2018)_isMissing', -0.0),
#  ('Parent/child indicator - Finance (FLAGS2019)_Child record - reports partial data but other data is included  with entity that is not a postsecondary institution',
#   0.0),
#  ('Parent/child indicator - Finance (FLAGS2019)_Parent record - includes data from branch campuses',
#   0.0),
#  ('Sector of institution (HD2018)_Private for-profit, 4-year or above', 0.0),
#  ('Sector of institution (HD2018)_Private for-profit, less-than 2-year', 0.0),
#  ('Sector of institution (HD2018)_Private not-for-profit, 2-year', -0.0),
#  ('Sector of institution (HD2018)_Private not-for-profit, 4-year or above',
#   -0.0),
#  ('Sector of institution (HD2018)_Public, 2-year', -0.0),
#  ('Sector of institution (HD2018)_Public, 4-year or above', -0.0),
#  ('Sector of institution (HD2018)_isMissing', -0.0),
#  ('State abbreviation (HD2018)_Alaska', -0.0),
#  ('State abbreviation (HD2018)_American Samoa', 0.0),
#  ('State abbreviation (HD2018)_Arizona', -0.0),
#  ('State abbreviation (HD2018)_Arkansas', -0.0),
#  ('State abbreviation (HD2018)_California', -0.0),
#  ('State abbreviation (HD2018)_Colorado', -0.0),
#  ('State abbreviation (HD2018)_Connecticut', -0.0),
#  ('State abbreviation (HD2018)_Delaware', -0.0),
#  ('State abbreviation (HD2018)_District of Columbia', -0.0),
#  ('State abbreviation (HD2018)_Federated States of Micronesia', 0.0),
#  ('State abbreviation (HD2018)_Georgia', -0.0),
#  ('State abbreviation (HD2018)_Guam', -0.0),
#  ('State abbreviation (HD2018)_Hawaii', -0.0),
#  ('State abbreviation (HD2018)_Idaho', -0.0),
#  ('State abbreviation (HD2018)_Indiana', -0.0),
#  ('State abbreviation (HD2018)_Iowa', -0.0),
#  ('State abbreviation (HD2018)_Kansas', -0.0),
#  ('State abbreviation (HD2018)_Kentucky', -0.0),
#  ('State abbreviation (HD2018)_Louisiana', -0.0),
#  ('State abbreviation (HD2018)_Maine', -0.0),
#  ('State abbreviation (HD2018)_Marshall Islands', -0.0),
#  ('State abbreviation (HD2018)_Maryland', 0.0),
#  ('State abbreviation (HD2018)_Massachusetts', -0.0),
#  ('State abbreviation (HD2018)_Michigan', -0.0),
#  ('State abbreviation (HD2018)_Minnesota', 0.0),
#  ('State abbreviation (HD2018)_Mississippi', 0.0),
#  ('State abbreviation (HD2018)_Missouri', 0.0),
#  ('State abbreviation (HD2018)_Montana', 0.0),
#  ('State abbreviation (HD2018)_Nebraska', 0.0),
#  ('State abbreviation (HD2018)_Nevada', 0.0),
#  ('State abbreviation (HD2018)_New Hampshire', 0.0),
#  ('State abbreviation (HD2018)_New Jersey', 0.0),
#  ('State abbreviation (HD2018)_New Mexico', 0.0),
#  ('State abbreviation (HD2018)_North Carolina', -0.0),
#  ('State abbreviation (HD2018)_North Dakota', 0.0),
#  ('State abbreviation (HD2018)_Northern Marianas', -0.0),
#  ('State abbreviation (HD2018)_Ohio', -0.0),
#  ('State abbreviation (HD2018)_Oklahoma', -0.0),
#  ('State abbreviation (HD2018)_Oregon', -0.0),
#  ('State abbreviation (HD2018)_Puerto Rico', -0.0),
#  ('State abbreviation (HD2018)_Rhode Island', 0.0),
#  ('State abbreviation (HD2018)_South Carolina', 0.0),
#  ('State abbreviation (HD2018)_South Dakota', 0.0),
#  ('State abbreviation (HD2018)_Tennessee', 0.0),
#  ('State abbreviation (HD2018)_Utah', 0.0),
#  ('State abbreviation (HD2018)_Vermont', 0.0),
#  ('State abbreviation (HD2018)_Virgin Islands', 0.0),
#  ('State abbreviation (HD2018)_Virginia', -0.0),
#  ('State abbreviation (HD2018)_West Virginia', 0.0),
#  ('State abbreviation (HD2018)_Wisconsin', -0.0),
#  ('State abbreviation (HD2018)_Wyoming', 0.0),
#  ('State abbreviation (HD2018)_isMissing', -0.0),
#  ('Other_Core_Expenses_As_Dollar_Amount', 4.427655241870282e-09),
#  ('Public_Service_Expenses_As_Dollar_Amount', 4.979757402125657e-09),
#  ('Government_Grants_As_Dollar_Amount', 8.005502361859014e-09),
#  ('Core_Revenues', 1.1092267475832382e-08),
#  ('Student_Service_Expenses_As_Dollar_Amount', 6.772825660571998e-08),
#  ('Total price for out-of-state students living on campus 2012-13 (DRVIC2012_RV)',
#   0.00024311934193059452),
#  ('Total women (EF2013B_RV  Undergraduate  Age 25 and over total)',
#   0.0006231473846211577),
#  ('Total women (EF2013B_RV  Undergraduate  Age under 25 total)',
#   0.0012299994975212474),
#  ('Grand total men instructional_staff', 0.0034339146117545786),
#  ('Grand total instructional_staff', 0.004948705955210227),
#  ('Race/ethnicity unknown women instructional_staff', 0.010083904067352363),
#  ('White men instructional_staff', 0.011332688711381732),
#  ('Percent of total enrollment that are American Indian or Alaska Native (DRVEF2013_RV)',
#   0.011584935008928323),
#  ('White total instructional_staff', 0.013031703292977098),
#  ('Hispanic or Latino men instructional_staff_as_percentage',
#   0.019568436800254708),
#  ('White women instructional_staff_as_percentage', 0.02203644972310264),
#  ('Two or more races total instructional_staff', 0.023970410442030073),
#  ('Asian women instructional_staff', 0.024492094233864125),
#  ('Hispanic or Latino men instructional_staff', 0.027323187196767396),
#  ('Black or African American women instructional_staff_as_percentage',
#   0.02950777127652237),
#  ('SAT Math 75th percentile score (IC2012_RV)', 0.03801777612227436),
#  ('Race/ethnicity unknown men instructional_staff_as_percentage',
#   0.046645294472410004),
#  ('Percent of total enrollment that are women (DRVEF2013_RV)',
#   0.04856938779690653),
#  ('Instruction_Expenses', 0.049769534229994875),
#  ('Native Hawaiian or Other Pacific Islander men instructional_staff_as_percentage',
#   0.05645940062278136),
#  ('Two or more races men instructional_staff_as_percentage',
#   0.0606843268323985),
#  ('Grand total men instructional_staff_as_percentage', 0.062331222545995074),
#  ('Private_Gifts', 0.06761008150452029),
#  ('Other_Core_Expenses', 0.07207068075299417),
#  ('Student-to-faculty ratio (EF2019D)', 0.08458524194357753),
#  ('Two or more races women instructional_staff', 0.08588345561116849),
#  ('Tuition_And_Fees', 0.08714235609023895),
#  ('Carnegie Classification 2018: Basic (HD2018)_Special Focus Four-Year: Other Technology-Related Schools',
#   0.09125071128385695),
#  ('Nonresident alien women instructional_staff', 0.09249851607336636),
#  ('Black or African American women instructional_staff', 0.10524615200549395),
#  ('Nonresident alien men instructional_staff_as_percentage',
#   0.10994928114987555),
#  ('Native Hawaiian or Other Pacific Islander total instructional_staff_as_percentage',
#   0.11082035838710823),
#  ('Investment_Return', 0.12189300942829981),
#  ('Percent of total enrollment that are Nonresident Alien (DRVEF2013_RV)',
#   0.12285993042242731),
#  ('Percent of full-time first-time undergraduates awarded any financial aid (SFA1819)',
#   0.13193353970358349),
#  ('Percent of total enrollment that are White (DRVEF2013_RV)',
#   0.1430388978078785),
#  ('Percent of total enrollment that are two or more races (DRVEF2013_RV)',
#   0.14349098338692795),
#  ('Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander (DRVEF2013_RV)',
#   0.15418904929361582),
#  ('Carnegie Classification 2018: Basic (HD2018)_Baccalaureate Colleges: Diverse Fields',
#   0.1613478370457852),
#  ('Other_Revenues', 0.16173878904773398),
#  ('Percent of total enrollment that are Hispanic/Latino (DRVEF2013_RV)',
#   0.18992949707254483),
#  ('State abbreviation (HD2018)_Washington', 0.20835099367983867),
#  ('State', 0.22345835113006693),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, highly residential',
#   0.25736250406268957),
#  ('American Indian or Alaska Native men instructional_staff',
#   0.25999454063561966),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, medium, highly residential',
#   0.28286193107401053),
#  ('Carnegie_Classification_Basic', 0.2878507430567829),
#  ('Percent of total enrollment that are Asian (DRVEF2013_RV)',
#   0.30606883711243643),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, very small, primarily nonresidential',
#   0.3285220087155317),
#  ('Research_Expenses', 0.3446237560325396),
#  ('American Indian or Alaska Native women instructional_staff_as_percentage',
#   0.38148540747334764),
#  ('State abbreviation (HD2018)_Pennsylvania', 0.38777062673527696),
#  ('Carnegie Classification 2018: Size and Setting (HD2018)_Four-year, small, primarily residential',
#   0.426883691189354),
#  ('Sector', 0.8023275349589379),
#  ('Carnegie_Classification_Size_Setting', 0.8233670379407649),
#  ('Sales_And_Services', 0.930692370837001),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Medium Programs",
#   0.9345254786739486),
#  ('ACT Composite 75th percentile score (IC2012_RV)', 0.9458434207001785),
#  ('Total women (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage',
#   1.0252626917732832),
#  ('State abbreviation (HD2018)_Florida', 1.1577884103422245),
#  ('Grand total (EF2013B_RV  Undergraduate  Age under 25 total)_as_percentage',
#   1.1781868974429388),
#  ("Carnegie Classification 2018: Basic (HD2018)_Master's Colleges & Universities: Larger Programs",
#   1.3739242126793354),
#  ('Parent/child indicator - Finance (FLAGS2019)_Not applicable',
#   1.4150913522374722),
#  ('Carnegie Classification 2018: Enrollment Profile (HD2018)_Exclusively undergraduate four-year',
#   2.015354043750489)]

# %% [markdown]
# # Use Non Linear Features

# %%
tips = px.data.tips()
fig = px.scatter(tips, x="total_bill", y="tip", trendline="ols")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0q/2w6362bn3v11r3hw5198hcvw0000gn/T/ipykernel_78429/2475931913.py in <module>
#       1 tips = px.data.tips()
# ----> 2 fig = px.scatter(tips, x="total_bill", y="tip", trendline="ols")
#       3 fig.show()
#
# ~/Desktop/DSP Env/venv/lib/python3.8/site-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#      67
#      68
#
# ~/Desktop/DSP Env/venv/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2109                     group[var] = 100.0 * group[var] / group_sum
#    2110
# -> 2111             patch, fit_results = make_trace_kwargs(
#    2112                 args, trace_spec, group, mapping_labels.copy(), sizeref
#    2113             )
#
# ~/Desktop/DSP Env/venv/lib/python3.8/site-packages/plotly/express/_core.py in make_trace_kwargs(args, trace_spec, trace_data, mapping_labels, sizeref)
#     356                     trace_patch["x"] = sorted_trace_data[args["x"]][non_missing]
#     357                     trendline_function = trendline_functions[attr_value]
# --> 358                     y_out, hover_header, fit_results = trendline_function(
#     359                         args["trendline_options"],
#     360                         sorted_trace_data[args["x"]],
#
# ~/Desktop/DSP Env/venv/lib/python3.8/site-packages/plotly/express/trendline_functions/__init__.py in ols(trendline_options, x_raw, x, y, x_label, y_label, non_missing)
#      41             )
#      42
# ---> 43     import statsmodels.api as sm
#      44
#      45     add_constant = trendline_options.get("add_constant", True)
#
# ModuleNotFoundError: No module named 'statsmodels'
